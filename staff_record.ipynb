# %% [markdown]
# # Staff cleanup #

# %%
import pandas as pd

# %%
authors = pd.read_csv("authors.csv")
staff = pd.read_csv("staff.csv")

# %% [markdown]
# ## `authors` ##

# %%
del authors["PUBLICATION_ID"]

# %%
authors = authors.sort_values("PERSON_ID", axis=0)

# %%
auth_pids = authors["PERSON_ID"].values
auth_pids = list(set(auth_pids))

# %%
auth_pn = {}
for i in auth_pids:
     auth_pn[i] = list(set(authors[authors["PERSON_ID"]==i]["PUBLISHED_NAME"].values))

# %%
auth_pn
# Out:
# {24576: ['SM Shilton', 'Siobhan M Shilton'],
#  57346: ['Tim Arnold'],
#  24581: ['Becky Conway-Campbell', 'BL Conway-Campbell'],
#  49161: ['Lyndsay M-L Coo'],
#  24586: ['Joanne Edgar', 'JL Edgar'],
#  16395: ['Francesco Mezzadri', 'F Mezzadri'],
#  49164: ['C. Howcroft', 'Chris Howcroft'],
#  19117: ['KCR Baldock', 'Katherine C R Baldock', 'Katherine C. R. Baldock'],
#  16403: ['Emma S. J. Robinson', 'ESJ Robinson', 'Emma S J Robinson'],
#  20: ['David Armstrong'],
#  24601: ['Pamela M King', 'PM King'],
#  16410: ['Siobhan M Mullan',
#   'Siobhan Mullan',
#   'Siobhan M. Mullan',
#   'SM Mullan',
#   'S. Mullan'],
#  49182: ['Kongtana Trakarnsanga'],
#  33: ['SB Barnes', 'Sally B Barnes', 'S B Barnes'],
#  8227: ["G.G D'Costa", "Gavin D'Costa", "GG D'Costa", "Gavin G D'Costa"],
#  24612: ['JW Harris'],
#  24615: ['F Giampapa'],
#  32811: ['F Fornetti', 'Francesco Fornetti'],
#  44: ['MH Barton'],
#  24621: ['TG Harrison', 'Tim G Harrison'],
#  1373: ['AG Hoare', 'A G Hoare'],
#  24627: ['Stan Zammit', 'Stanley Zammit', 'S Zammit', 'S. Zammit'],
#  16436: ['JE Weldes', 'Jutta Weldes'],
#  16438: ['Christopher J. Adams', 'CJ Adams', 'C. J. Adams', 'C.J Adams'],
#  57: ['PM Bennett'],
#  16443: ['C Wells'],
#  24638: ['SM Jones', 'Sam M Jones'],
#  27317: ['C. Patrick Royall', 'C P Royall', 'C.P Royall', 'CP Royall'],
#  16448: ['LA Calvo-Bado',
#   'Rosemary Grogono-Thomas',
#   'R. Grogono-Thomas',
#   'R Grogono-Thomas'],
#  27318: ['Steffan G Davies', 'SG Davies', 'S.G Davies'],
#  49222: ['Pia N Sartor', 'P. Sartor', 'Pia Sartor'],
#  49224: ['Jon X Eguia', 'Jon X. Eguia'],
#  77: ['Michael P. Allen', 'M. .. . P. .. Allen'],
#  49230: ['Maximilian J. Werner', 'M. J. Werner', 'Maximilian J Werner'],
#  32848: ['Emma J Stone', 'E J Stone', 'EJ Stone'],
#  16465: ['DG Punter', 'David Punter', 'D.G Punter'],
#  83: ['Michael A Adams',
#   'M A Adams',
#   'M.A Adams',
#   'Michael Anthony Adams',
#   'MA Adams',
#   'Mike A Adams'],
#  8277: ['Rachel A Lart', 'RA Lart'],
#  8278: ['N. A J Lieven', 'NAJ Lieven', 'Nicholas A J Lieven'],
#  16471: ['Rob Andrews',
#   'Rob C Andrews',
#   'R. C. Andrews',
#   'RC Andrews',
#   'R.C Andrews'],
#  27281: ['Andrew Barber'],
#  24665: ['GRI Barker',
#   'G R I Barker',
#   'Gareth R. I. Barker',
#   'Gareth R I Barker',
#   'Gareth Barker'],
#  24670: ['M. Hickman', 'Matthew Hickman', 'M Hickman'],
#  49247: ['Stephen J Cross'],
#  8288: ['VD Zajko', 'V.D Zajko', 'Vanda D Zajko'],
#  32866: ['ST Creavin',
#   'Sam Creavin',
#   'Sam T Creavin',
#   'Samuel T Creavin',
#   'Samuel Thomas Creavin',
#   'S. T. Creavin'],
#  32737: ['T Davies-Barnard'],
#  24677: ['Surinder Kaur', 'S Kaur'],
#  24678: ['Mark R Duffield', 'MR Duffield'],
#  103: ['Roger W. Alder', 'RW Alder'],
#  104: ['S J Allen',
#   'Shelley J Allen',
#   'Shelley J Allen-Birt',
#   'Shelley Allen-Birt',
#   'SJ Allen'],
#  105: ['WJ Armitage', 'W J Armitage'],
#  24683: ['EL Morley', 'Erica L Morley'],
#  4114: ['Michael Wisnom',
#   'M.R Wisnom',
#   'MR Wisnom',
#   'M. R. Wisnom',
#   'Michael R Wisnom',
#   'Michael R. Wisnom'],
#  24687: ['K Shallcross'],
#  16499: ['CR Tidmarsh'],
#  16500: ['M. Homer', 'ME Homer', 'M. E. Homer', 'Martin E Homer'],
#  25100: ['R Granell', 'R. Granell', 'Raquel Granell'],
#  16511: ['Jeremy Horwood', 'JP Horwood', 'J. Horwood', 'Jeremy P Horwood'],
#  49281: ['Siyang Xiong'],
#  32899: ['A \\00C1vila Ibarra', 'A Avila Ibarra'],
#  132: ['MG Anderson', 'Malcolm G Anderson'],
#  4118: ['Sarah Payne', 'S Payne'],
#  24710: ['Jelena Savovic', 'J Savovic'],
#  33771: ['D. Bonneau', 'Damien Bonneau'],
#  16525: ['Sian M Noble', 'Sian M. Noble', 'Sian Noble', 'S Noble', 'S. Noble'],
#  32910: ['Lorna Hodgson', 'Lorna R Hodgson'],
#  24721: ['Anthony J Everett', 'AJ Everett'],
#  24724: ['R Hughes',
#   'R A Hughes',
#   'RA Hughes',
#   'Rachael Hughes',
#   'Rachael A Hughes'],
#  32918: ['Matthew Hazell'],
#  49303: ['Timothy M Fowler', 'T. Fowler'],
#  153: ['PJ Barham'],
#  8346: ['M Bailey', 'Mick Bailey'],
#  65702: ['Argun Cakir'],
#  57512: ['O. S P Davis', 'Oliver S P Davis'],
#  49321: ['Margit Dirscherl'],
#  32942: ['Graham D. Marshall',
#   'G. D. Marshall',
#   'GD Marshall',
#   'Graham David Marshall'],
#  32943: ['A. R. McMillan', 'Alex McMillan', 'Alex R McMillan'],
#  177: ['GG Balint-Kurti'],
#  178: ['MG Basker', 'M.G Basker'],
#  16565: ['Helen Williams', 'H Williams'],
#  24758: ['H Wang'],
#  184: ['William E. Banks'],
#  185: ['Roger Barker', 'Roger A. Barker'],
#  189: ['A. R S Barr', 'AR Barr', 'Alistair R S Barr', 'ARS Barr'],
#  34165: ['Rachel C. M. Warnock', 'Rachel C M Warnock'],
#  24768: ['R Skinner', 'Robert A Skinner'],
#  193: ['P. Bartlett', 'P Bartlett', 'Paul Bartlett'],
#  32963: ['Sunita Procter'],
#  32964: ['J Liu', 'Jian Liu'],
#  21878: ['CM McKinnon', 'Caroline M McKinnon', 'C.M McKinnon'],
#  8225: ['Graeme Henderson', 'G Henderson'],
#  33286: ['Paul Bishop'],
#  5495: ['R. B. Sessions',
#   'Richard B. Sessions',
#   'Richard Sessions',
#   'Richard B Sessions',
#   'R Sessions',
#   'R.B Sessions',
#   'RB Sessions'],
#  16588: ['AJ Searle', 'Aidan Searle', 'A. Searle', 'Aidan J Searle'],
#  49361: ['Peter J D Scott'],
#  49362: ['A. Marcos'],
#  32979: ['MP Ellison', 'Michael P Ellison'],
#  16596: ['Michael D Patterson', 'M. D. Patterson', 'Michael Patterson'],
#  24792: ['Helen Baxter', 'H. Baxter', 'H Baxter', 'Helen A Baxter'],
#  31440: ['MS Gulliver', 'Mike Gulliver'],
#  8421: ['M Davies', 'Maria Davies'],
#  16615: ['Angela C M Rowe', 'Angela Rowe', 'AC Rowe', 'Angela C. Rowe'],
#  28711: ['Sarah L Bell', 'Sarah Bell', 'SL Gunn'],
#  27346: ['DM Christmas'],
#  238: ['David Blockley', 'David I Blockley', 'DI Blockley'],
#  16626: ['Massimo Antognozzi', 'M Antognozzi'],
#  65783: ['Kate Guthrie'],
#  8441: ['SE Heslop'],
#  25983: ['Karen Coulman', 'KD Coulman', 'K. Coulman', 'Karen D Coulman'],
#  33020: ['Jason Matharu'],
#  57599: ['Julie B Dunne'],
#  8448: ['H Mellor', 'Harry Mellor'],
#  12331: ['Keith J Edwards', 'K.J Edwards', 'Keith J. Edwards', 'KJ Edwards'],
#  33029: ['F MacKichan', 'F Mackichan', 'Fiona MacKichan'],
#  16647: ['Steven J Harper', 'Steven J. Harper', 'S J Harper', 'SJ Harper'],
#  16649: ['PJ Gardiner'],
#  23255: ['Walterio Mayol-Cuevas',
#   'W Mayol-Cuevas',
#   'Walterio W Mayol-Cuevas',
#   'Mayol-Cuevas Walterio',
#   'WW Mayol-Cuevas'],
#  7203: ['A. R. Baker'],
#  12333: ['Claire S. Grierson',
#   'C.S Grierson',
#   'CS Grierson',
#   'Claire Grierson',
#   'Claire S Grierson'],
#  33044: ['Peter Bennett', 'Peter D. Bennett'],
#  50564: ['Miriam Snellgrove'],
#  13103: ['David Lodge', 'D Lodge'],
#  8482: ['David A Richards', 'DA Richards'],
#  36913: ['A Papadaki', 'Angeliki Papadaki', 'A. Papadaki'],
#  33064: ['Rachel M Dommett', 'Rachel Dommett', 'R Dommett', 'R M Dommett'],
#  33065: ['V L H Roberts', 'Veronica Roberts'],
#  302: ['Richard G Brereton', 'Richard G. Brereton'],
#  16690: ['CE Whittles', 'Cheryl Whittles'],
#  49203: ['D Carwardine', 'Darren Carwardine'],
#  65844: ['Elinor Bowen'],
#  35550: ['Fabiana A Gomez'],
#  58761: ['Katie B Blakemore'],
#  32820: ['Andrew D A C Smith', 'ADAC Smith'],
#  315: ['Patricia M Broadfoot', 'PM Broadfoot', 'P.M Broadfoot'],
#  24892: ['David A Cottrell'],
#  321: ['DR Brookshaw'],
#  24898: ['K.J Morgan', 'KJ Morgan', 'Karen J Morgan', 'Karen Morgan'],
#  8515: ['KG Hallett'],
#  50572: ['Lucy H Brunt'],
#  330: ['J. Charlet', 'Keith Brown', 'Keith W Brown', 'KW Brown'],
#  16715: ['D. Lawlor',
#   'DA Lawlor',
#   'Debbie Lawlor',
#   'Debbie Anne Lawlor',
#   'D A Lawlor',
#   'D Lawlor',
#   'Debbie A Lawlor',
#   'Debbie A. Lawlor',
#   'D. A. Lawlor'],
#  49486: ['Kimberly J Hannam', 'Kimberly Hannam'],
#  16720: ['R E Wilson',
#   'R. E. Wilson',
#   'RE Wilson',
#   'Eddie Wilson',
#   'R. Eddie Wilson'],
#  33105: ['Lei Liu'],
#  24914: ['DE Odd', 'David Edward Odd', 'David E Odd', 'David Odd', 'D. Odd'],
#  19171: ['P Sanchez-Baracaldo', 'Patricia Sanchez-Baracaldo'],
#  35473: ['Nicholas L Turner', 'Nicholas Turner'],
#  16730: ['MFE Damian',
#   'Markus F E Damian',
#   'Markus F. Damian',
#   'Markus F Damian',
#   'M. F. Damian'],
#  33115: ['Adam Sales', 'Adam J B Sales'],
#  348: ['Roger Bullock'],
#  351: ['Peter C. Bunniss', 'PC Bunniss', 'P. Bunniss'],
#  49504: ['John P Kemp', 'John P. Kemp', 'J. P. Kemp'],
#  33123: ['Clive G. Bowsher', 'Clive G Bowsher', 'CG Bowsher'],
#  49508: ['Lucia Marucci'],
#  57701: ['Gemma Moss'],
#  24934: ['CA Barter', 'C.A Barter'],
#  57705: ['Helmut Hauser'],
#  57706: ['Raffaele De Risi', 'R. De Risi', 'R. de Risi'],
#  46385: ['Alberto Acerbi'],
#  16751: ['ME Phillips', 'Mary E Phillips', 'Mary Louise Phillips'],
#  16752: ['DN Sheppard',
#   'D.N Sheppard',
#   'David N. Sheppard',
#   'David N Sheppard'],
#  33137: ['Daniel Montoya', 'D Montoya'],
#  65906: ['Alex Barlow'],
#  34195: ['N Jade Thai', 'Ngoc Jade Thai', 'Ngoc J Thai'],
#  24949: ['SR Shannon', 'Sarah R Shannon'],
#  33143: ['Olivia Anna Skrobot'],
#  24954: ['J. Gottsmann',
#   'Joachim Gottsmann',
#   'JH Gottsmann',
#   'Joachim H Gottsmann'],
#  16763: ['CJ Hawkesworth',
#   'Chris Hawkesworth',
#   'C. J. Hawkesworth',
#   'Chris J Hawkesworth'],
#  33148: ['Mark C. Eisler', 'M. C. Eisler', 'MC Eisler'],
#  16773: ['Andrew David Dick',
#   'A D Dick',
#   'Andrew D Dick',
#   'AD Dick',
#   'Andrew D. Dick',
#   'A Dick',
#   'A.D Dick'],
#  24969: ['Matt W Jones', 'MW Jones'],
#  24973: ['Julie Mytton', 'Julie A Mytton'],
#  24979: ['Peter R C Collins', 'Peter Collins'],
#  16788: ['Stephen Banfield', 'SD Banfield', 'Stevens Douglas'],
#  405: ['John S W Carpenter', 'J Carpenter'],
#  30105: ['R Curnock'],
#  410: ['Deborah A Carter', 'D.A Carter', 'D Carter'],
#  412: ['JA Lane'],
#  10925: ['JY Jeremy'],
#  419: ['TF Carver', 'Terrell F Carver'],
#  33188: ['Zoe M Leinhardt', 'ZM Leinhardt', 'Zoe M. Leinhardt'],
#  25004: ['Jo E Crow', 'J.E Crow', 'JE Crow'],
#  25011: ['Dickon Young', 'D. Young'],
#  16822: ['George Nash', 'GH Nash'],
#  442: ['David Cherns', 'D Cherns', 'D. Cherns'],
#  16827: ['Edward R C Hornibrook',
#   'ERC Hornibrook',
#   'E. R. C. Hornibrook',
#   'Edward Hornibrook'],
#  33215: ['Chunyun Du', 'C Du'],
#  16834: ['G Liveley'],
#  8643: ['Jan Frayne', 'J. Frayne', 'J Frayne'],
#  16836: ['Ludivine B E Garside'],
#  16844: ['P. G. Kehoe',
#   'Patrick G Kehoe',
#   'Patrick G. Kehoe',
#   'PG Kehoe',
#   'Patrick Gavin Kehoe',
#   'P Kehoe',
#   'Patrick Kehoe'],
#  25038: ['Stephan Lewandowsky'],
#  33231: ['Kevin P Collins'],
#  33234: ['Kristopher Magee'],
#  33235: ['Sanaya Pardiwalla'],
#  468: ['S.M Burgess',
#   'S Burgess',
#   'Simon M Burgess',
#   'Simon Burgess',
#   'SM Burgess'],
#  33239: ['Joanna R Hall'],
#  33242: ['Felix J Mercer Moss'],
#  33248: ['Victoria Jackson'],
#  15603: ['J. Heron', 'J Heron', 'Jon E Heron', 'Jon Heron'],
#  25058: ['A Collins', 'Andrew M. Collins', 'Andrew M Collins'],
#  19195: ['Yvonne K Sherratt'],
#  484: ['JA Burrow'],
#  58790: ['A. R. Melro'],
#  24657: ['A Skordas'],
#  25064: ['Jennifer C Palmer',
#   'Jennifer Palmer',
#   'Jennifer C. Palmer',
#   'JC Palmer'],
#  16874: ['RD Sheldon', 'Richard D Sheldon'],
#  25070: ['PJ Hotston Moore'],
#  16467: ['D Patsios', 'Demi Patsios'],
#  16886: ['CE Truman',
#   'C. E. Truman',
#   'Christopher Truman',
#   'Christopher E Truman'],
#  16889: ['Simon C Satchell', 'Simon Satchell', 'SC Satchell', 'S C Satchell'],
#  16890: ['LA Culliford', 'Lucy Culliford', 'Lucy A Culliford'],
#  16891: ['Raimondo Ascione', 'R. Ascione', 'R Ascione'],
#  8708: ['Maria M Usowicz', 'MM Usowicz'],
#  24662: ['MV Joubert', 'Marie V Joubert', 'M V Joubert'],
#  16902: ['P.J Booth', 'Paula J. Booth', 'Paula J Booth', 'PJ Booth'],
#  15105: ['Eugene Lloyd', 'E Lloyd'],
#  13806: ['John P Moppett', 'John Moppett'],
#  8716: ['Karim T A Malik', 'Karim Malik', 'KTA Malik', 'K Malik'],
#  16911: ['Y Netrusov', 'Yuri Netrusov'],
#  33296: ['Sarah A. Stuart', 'Sarah A Stuart'],
#  66065: ['Peter Insole'],
#  531: ['R R Clements', 'RR Clements'],
#  49684: ['Foluke I Ipinyomi'],
#  33302: ['Ore Francis'],
#  16919: ['JS Patel', 'J Patel'],
#  14188: ['S. B. Dugdale', 'SB Dugdale', 'S.B Dugdale', 'Stephen B Dugdale'],
#  57884: ['Francesco Alderisio'],
#  20570: ['MP Crump',
#   'M.P Crump',
#   'Matthew Crump',
#   'M. P. Crump',
#   'Matthew P Crump',
#   'Matthew P. Crump'],
#  8734: ['M Tranter', 'Martyn Tranter', 'M. Tranter'],
#  49695: ['Bryony Enright'],
#  33314: ['Tim J Satchwell',
#   'Timothy J Satchwell',
#   'TJ Satchwell',
#   'T.J Satchwell',
#   'T J Satchwell'],
#  16931: ['J. D. Dewsbury', 'John-David C Dewsbury', 'J-DC Dewsbury'],
#  16938: ['Shailen Nandy', 'S Nandy'],
#  19207: ['E V Washbrook',
#   'Elizabeth Washbrook',
#   'EV Washbrook',
#   'E.V Washbrook'],
#  27400: ['David I. Whiteside', 'DI Whiteside'],
#  564: ['E J Collins', 'EJ Collins'],
#  94: ['Mike Ashfold',
#   'M.N.R Ashfold',
#   'MNR Ashfold',
#   'M. N. R. Ashfold',
#   'Michael N.R. Ashfold',
#   'Michael N R Ashfold',
#   'Michael N. R. Ashfold'],
#  25145: ['A.M Hetherington',
#   'AM Hetherington',
#   'Alistair Hetherington',
#   'Alistair M Hetherington',
#   'Alistair M. Hetherington'],
#  33340: ['Karen Bell'],
#  575: ['Neil G. Connelly'],
#  8769: ['D. G. Cussans',
#   'David G Cussans',
#   'D. Cussans',
#   'David Cussans',
#   'D.G Cussans',
#   'DG Cussans'],
#  16963: ['HR Whay',
#   'H. Rebecca Whay',
#   'H R Whay',
#   'Helen R Whay',
#   'H. R. Whay'],
#  8775: ['T Gallagher', 'Tim C Gallagher', 'Timothy Gallagher'],
#  35597: ['R. Malkin', 'Rob Malkin'],
#  16976: ['Simon Armour', 'S. Armour', 'Simon M D Armour', 'SMD Armour'],
#  49747: ['F Drenos', 'F. Drenos', 'Fotios Drenos'],
#  25172: ['Christopher D C Jones'],
#  33366: ['E.R.M Fortin', 'ERM Fortin', 'Elizabeth R M Fortin'],
#  25175: ['L Tilley'],
#  25177: ['C Green'],
#  16988: ['Colette Reid', 'Colette M Reid', 'CM Reid'],
#  605: ['NJ Cornwell'],
#  25183: ['Rosey Mushens'],
#  608: ['Michael D Costen'],
#  25185: ['L Johnson', 'Laura Johnson', 'Laura M Johnson'],
#  25186: ['Kristian Aquilina', 'K Aquilina'],
#  13755: ['SC Langton Hewer', 'Simon Langton-Hewer'],
#  8804: ['S. M. Ring',
#   'S M Ring',
#   'Susan M. Ring',
#   'Susan Ring',
#   'S. Ring',
#   'SM Ring',
#   'Susan M Ring'],
#  33386: ['Jane E. Ferrie', 'JE Ferrie', 'Jane E Ferrie'],
#  33387: ['Alex Cooke', 'Alexandra E Cooke'],
#  17004: ['C. Metcalfe', 'Chris Metcalfe', 'C Metcalfe'],
#  31506: ['Tatyana Andrienko', 'T. N. Andrienko'],
#  25200: ['P Curnow', 'Paul Curnow'],
#  33394: ['Paddy W Carter'],
#  33395: ['Jie Chen'],
#  49787: ['Aksel Ersoy'],
#  31509: ['Lucy Rogers'],
#  50624: ['Timothy A. Shuttleworth'],
#  33417: ['Jenny M Riker'],
#  66186: ['Maria Carolina Borges', 'Maria C Borges'],
#  33419: ['R M Pearson',
#   'Rebecca Pearson',
#   'Rebecca M Pearson',
#   'RM Pearson',
#   'R Pearson'],
#  25230: ['HL Scott', 'Helen L Scott'],
#  17041: ['IR Dale', 'I R Dale'],
#  34243: ['Nick Nourse'],
#  8855: ['D. R. Bull',
#   'David R. Bull',
#   'David R Bull',
#   'DR Bull',
#   'David Bull'],
#  1476: ['Yaz L Iles-Caven'],
#  32879: ['Karen Tucker'],
#  33437: ['Helen E Thomas', 'Helen Thomas'],
#  19227: ['RM Burt'],
#  17062: ['MJ Cryan',
#   'Martin J Cryan',
#   'M. J. Cryan',
#   'M J Cryan',
#   'Martin Cryan',
#   'Martin J. Cryan',
#   'M. Cryan'],
#  12401: ['TA Novitz', 'T.A Novitz', 'Tonia A Novitz', 'Tonia Novitz'],
#  17065: ['Z Cai', 'Zhiwei Cai'],
#  33450: ['Geoffrey N Kilgour'],
#  8881: ['HP Woodfield', 'H.P Woodfield', 'Helen P Woodfield'],
#  8882: ['G Angelini',
#   'G. D. Angelini',
#   'Gianni D Angelini',
#   'Gianni Angelini',
#   'Gianni D. Angelini'],
#  8883: ['T J Peters',
#   'Tim Peters',
#   'Tim J Peters',
#   'T.J Peters',
#   'TJ Peters',
#   'Tim J. Peters',
#   'T. J. Peters'],
#  58038: ['Andrew W Morden', 'Andrew Morden'],
#  24692: ['Bernard Stark',
#   'Bernard H Stark',
#   'BH Stark',
#   'B. H. Stark',
#   'Bernard H. Stark'],
#  25280: ['Kate A House', 'KA House', 'Kate House'],
#  8900: ['JM Sparrow'],
#  15137: ['T. Horseman', 'TR Horseman'],
#  58056: ['Albert Power'],
#  25289: ['Lesley Wood', 'L Wood'],
#  33482: ['David P Billington', 'D. Billington'],
#  25291: ['Anthony J. Croxford',
#   'A J Croxford',
#   'Anthony J Croxford',
#   'AJ Croxford',
#   'Anthony Croxford',
#   'A. J. Croxford'],
#  33488: ['D. Liu', 'D Liu', 'Dong Liu'],
#  8914: ['MC Wilson', 'Marieangela C. Wilson'],
#  723: ['John Davis', 'John M Davis', 'John P Davis', 'JP Davis'],
#  66262: ['Fabio Parmeggiani'],
#  20601: ['Poppy T E Statham', 'P Statham', 'PTE Statham'],
#  66266: ['A. Nassehi', 'Aydin Nassehi'],
#  8925: ['Paul Bates',
#   'Paul D Bates',
#   'P. Bates',
#   'PD Bates',
#   'P. D. Bates',
#   'Paul D. Bates'],
#  58081: ['Y Tan'],
#  740: ['J. Day', 'John C. C. Day', 'JCC Day', 'John C C Day'],
#  20604: ['R W J Lee', 'Richard Lee', 'RWJ Lee', 'Richard W J Lee'],
#  33514: ['Paul Giles', 'P. Giles'],
#  33516: ['E.J Clement', 'Emyr J Clement', 'EJ Clement'],
#  8941: ['Matthew A. Hoghton', 'MA Hoghton', 'Matthew A Hoghton'],
#  753: ['Richard M. Denton'],
#  33523: ['Tom S Williams'],
#  25342: ['Clare Y England'],
#  33535: ['J. E. Darnbrough'],
#  769: ['RN Dixon', 'R. N. Dixon', 'Richard N Dixon', 'Richard N. Dixon'],
#  35627: ['Nicola Marie Stock'],
#  33545: ['David J. Platt'],
#  25354: ['S Hossain', 'S. Hossain'],
#  17163: ['A Baumbach', 'Andreas Baumbach'],
#  17164: ['CJ Annen', 'Catherine J Annen'],
#  25361: ['Noemi Lendvai'],
#  33556: ['Shu Sen Chang',
#   'S Chang',
#   'Shu-Sen Chang',
#   'S. S. Chang',
#   'S-S Chang'],
#  8982: ['Mark Horton', 'Mark C Horton'],
#  17183: ['Neil A. Fox', 'Neil A Fox', 'N.A Fox', 'NA Fox'],
#  8995: ['SL Lightman',
#   'Stafford Lightman',
#   'Stafford L. Lightman',
#   'Stafford L Lightman',
#   'S L Lightman'],
#  33572: ['J. Ross'],
#  805: ['W Doyle'],
#  33574: ['Simon Hamlin', 'S. Hamlin'],
#  25383: ['K. B. Blyuss'],
#  9002: ['S. John Hogan', 'SJ Hogan', 'S. J. Hogan', 'S J Hogan'],
#  25388: ['MacIej Klemm', 'M. Klemm', 'M Klemm', 'Maciej Klemm'],
#  9006: ['Cathy Williams', 'C Williams', 'Cathy E M Williams'],
#  25391: ['NM Redmond', 'Niamh M Redmond'],
#  17201: ['A.P Davis', 'AP Davis', 'Anthony P. Davis'],
#  33586: ['Mateusz Bocian'],
#  58163: ['Dylan H. Mahler', 'Dylan H Mahler', 'Dylan Mahler', 'D. H. Mahler'],
#  9012: ['D J Nutt',
#   'David Nutt',
#   'David J Nutt',
#   'D. J. Nutt',
#   'David J. Nutt',
#   'DJ Nutt'],
#  9013: ['Jayne E Bailey',
#   'Jayne Bailey',
#   'J. E. Bailey',
#   'JE Bailey',
#   'Jayne E. Bailey'],
#  66358: ['A Kathrani', 'Aarti Kathrani'],
#  58167: ['Johanna Galloway'],
#  58170: ['Rebecca Kandiyali'],
#  17212: ['Paul Smith'],
#  66367: ['Benedetta Lomi'],
#  25408: ['S Knippschild'],
#  66373: ['J Bell'],
#  33610: ['A Laing', 'A. Laing', 'Anthony Laing'],
#  33611: ['JHT Williams', 'J Williams', 'Jonny  Williams'],
#  25424: ['D Steer', 'Damian Steer', 'Damian M Steer'],
#  27448: ['N Fineman'],
#  57486: ['Abigail C Lay'],
#  4120: ['RML Gethin', 'Rupert M L Gethin', 'R.M.L Gethin'],
#  25431: ['CRC Paul'],
#  25435: ['MJ Toscano', 'M Toscano', 'Michael Toscano', 'Michael J Toscano'],
#  9052: ['Jonathan Evans', 'J Evans', 'Jonathan R. Evans'],
#  9053: ['Janet E L Corry', 'JEL Corry'],
#  25441: ['Marcus Drake',
#   'Marcus J. Drake',
#   'Marcus J Drake',
#   'M Drake',
#   'M. Drake'],
#  17251: ['A. E. Ades',
#   'AE Ades',
#   'Anthony E Ades',
#   'A. Ades',
#   'Anthony E. Ades',
#   'A E Ades'],
#  9063: ['Marcella J Wyatt', 'MJ Wyatt', 'Marcella Wyatt'],
#  9067: ['Josie Briscoe', 'J Briscoe', 'Josie M Briscoe'],
#  878: ['Alan M. Emond', 'AM Emond', 'Alan M Emond', 'A Emond', 'Alan Emond'],
#  33647: ['Li-Chen Han'],
#  17264: ['Allison Blair', 'A Blair'],
#  25398: ['John R Terry', 'JR Terry'],
#  885: ['DV Evans', 'D. V. Evans', 'David V Evans'],
#  21993: ['Johanna Trinder'],
#  25464: ['J Liu'],
#  890: ['R. Evans', 'Robert Evans', 'R Evans'],
#  50043: ['Daisy Townsend'],
#  9085: ['Timothy W Mowl'],
#  17278: ['L.E.N Rees', 'LEN Rees'],
#  897: ['J Eveson', 'J W Eveson'],
#  50051: ['Su Lin Lewis'],
#  9092: ['DS Jessop', 'David S Jessop', 'David S. Jessop'],
#  17285: ['SJ Mundell', 'Stuart J Mundell', 'Stuart Mundell', 'S J Mundell'],
#  9094: ['Joe Quarini', 'G L Quarini', 'GL Quarini', 'G. L. Quarini'],
#  9096: ['James Brennan'],
#  25481: ['Mike A Jones', 'M Jones'],
#  50059: ['Wen Y Ding'],
#  908: ['Elaine  Farmer', 'ERG Farmer', 'E.R.G Farmer', 'Elaine R G Farmer'],
#  50061: ['Chris Bell'],
#  25491: ['M. Jepson', 'Marcus J Jepson', 'MJ Jepson', 'Marcus Jepson'],
#  9109: ['MH Lowenberg',
#   'M. Lowenberg',
#   'Mark Lowenberg',
#   'Mark H Lowenberg',
#   'M. H. Lowenberg',
#   'Mark H. Lowenberg'],
#  53401: ['F. Pappenberger', 'Florian Pappenberger'],
#  9112: ['A R Nix',
#   'A. R. Nix',
#   'Andrew R. Nix',
#   'Andrew R Nix',
#   'Andrew Nix',
#   'AR Nix'],
#  33689: ['B. S. Truscott'],
#  922: ['Steve Fenton', 'C S Fenton', 'CS Fenton'],
#  11077: ['Steven Phillipps', 'S Phillipps', 'S. Phillipps'],
#  33698: ['S Gerhand'],
#  33699: ['Marios Hopkins Hatzopoulos', 'Marios T Hopkins Hatzopoulos'],
#  9124: ['Andrew Levy', 'A Levy'],
#  17318: ['H T Amos', 'T Amos'],
#  936: ['S Finerty'],
#  33708: ['Mehdi M Kashani', 'Mehdi  Kashani', 'Mohammad M Kashani'],
#  944: ['KDP Flanagan'],
#  22003: ['S Koutsikou', 'Stella Koutsikou'],
#  17332: ['A. Carrington', 'A Carrington', 'Antony Carrington'],
#  9141: ['G Welsh', 'Gavin I Welsh', 'G I Welsh'],
#  13125: ['Jenny A Hurcombe'],
#  50104: ['Sami Stouli'],
#  17337: ['Rachel J Aitken'],
#  25531: ['Julie MacLeavy', 'J MacLeavy'],
#  33724: ['Guillaume Chanoit', 'GPA Chanoit', 'G Chanoit', 'G P A Chanoit'],
#  22400: ['Jenny Mason'],
#  17352: ['JA Jefferson', 'Judith A Jefferson'],
#  969: ['Edward R B Forman', 'ERB Forman'],
#  970: ['RS Forrest', 'Raymond S Forrest', 'Ray Forrest', 'R.S Forrest'],
#  25548: ['Nicola Cogan', 'NM Cogan'],
#  976: ['B Foster'],
#  33750: ['Richard J Lock',
#   'R. J. Lock',
#   'R J Lock',
#   'RJ Lock',
#   'Richard J. Lock'],
#  25559: ['A Shterenlikht', 'A. Shterenlikht', 'Anton Shterenlikht'],
#  25560: ['O. T. Johnson', 'Oliver T Johnson', 'OT Johnson', 'Oliver Johnson'],
#  9179: ['IG Winson'],
#  33756: ['N\\00E1ndor Terkovics'],
#  9181: ['S Price', 'Simon Price'],
#  25566: ['Joya Pawade', 'J. Pawade'],
#  991: ['Clive R Frankish', 'CR Frankish'],
#  17376: ['NE Hussey', 'N.E Hussey', 'N. E. Hussey'],
#  17377: ['Sharon B Mitchell'],
#  9186: ['Hind Saidani-Scott', 'H. Saidani-Scott', 'H Saidani-Scott'],
#  997: ['Norman H. Freeman'],
#  31569: ['Ian Bailey'],
#  9193: ['Tracey J Collard', 'TJ Collard'],
#  1002: ['AL Friedman', 'A Friedman'],
#  25579: ['Celia L Gregson', 'C L Gregson', 'CL Gregson', 'Celia L. Gregson'],
#  24175: ['Judith Masson', 'Judith M Masson', 'J.M Masson', 'JM Masson'],
#  25582: ['A Wilkins', 'Alastair Wilkins'],
#  66544: ['Rosalyn Moran', 'R J Moran', 'Rosalyn J Moran'],
#  17397: ['TA Unwin'],
#  17404: ['P Brindle'],
#  25599: ['MM Greenslade'],
#  17410: ['David S Kessler', 'D Kessler', 'D. Kessler', 'David Kessler'],
#  37037: ['Micky Willmott'],
#  12882: ['Jeremy C Phillips',
#   'Jeremy C. Phillips',
#   'JC Phillips',
#   'J. C. Phillips'],
#  17427: ['Nils Langer', 'N Langer'],
#  9236: ['L. Duffy'],
#  25949: ['Jessica C Watson'],
#  33815: ['Luke Kreczko', 'Lukasz Kreczko'],
#  25625: ['RC Williamson', 'R.C Williamson', 'Roz C Williamson'],
#  17437: ['Christine M. Janis'],
#  26117: ['Tijl De Bie', 'Tijl  De Bie', 'Bie Tijl De', 'Tijl E P De Bie'],
#  66592: ['M Rolinski', 'Michal Rolinski'],
#  25131: ['A. Solomin'],
#  33831: ['David Carslake'],
#  25641: ['P. R. Burton',
#   'Paul R. Burton',
#   'Paul Burton',
#   'P Burton',
#   'Paul R Burton'],
#  25644: ['JA Carstairs', 'Jamie Carstairs', 'Jamie A Carstairs'],
#  17455: ['Deborah K Shoemark',
#   'DK Shoemark',
#   'Deborah Shoemark',
#   'D. K. Shoemark'],
#  12038: ['Hua Lin', 'H Lin'],
#  17461: ['KJ Bradley', 'Kate J. Bradley', 'Kate J Bradley'],
#  33848: ['Risto A Kauppinen',
#   'Risto Kauppinen',
#   'RA Kauppinen',
#   'R A Kauppinen'],
#  33850: ['Peter J. Bygrave', 'P. J. Bygrave'],
#  33854: ['C. H. Zhong', 'Cheng Huan Zhong'],
#  25663: ['Dawn Harrison'],
#  33856: ['Brioch J C Hemmings'],
#  1090: ['Jean Golding',
#   'J Golding',
#   'M J Golding',
#   'Jean Golding (nee Fedrick)',
#   'Jean Golding '],
#  33859: ['Andrew M. Chapman'],
#  1093: ['AR Goldsmith'],
#  33863: ['Elena M Couce', 'Elena Couce', 'E Couce'],
#  9288: ['S. Hanna', 'S Hanna', 'Simon Hanna'],
#  17932: ['A El-Turki'],
#  33866: ['Tim S. Coope', 'Timothy S Coope', 'T. S. Coope'],
#  33867: ['CM Greatwood', 'Colin Greatwood'],
#  33872: ['James White', 'J. A. P. White', 'James A P White'],
#  24760: ['Lynn Molloy'],
#  33874: ['Marco Capuzzi'],
#  33875: ['A. Brinkmeyer', 'Alex Brinkmeyer'],
#  17492: ['Catherine F Borwick'],
#  17493: ['Helen Cramer', 'Helen A Cramer', 'H Cramer'],
#  33878: ['Steve E Bullock'],
#  32953: ['SL Southern', 'Samantha L Southern'],
#  26127: ['Elavazhagan Chakkarapani', 'E Chakkarapani', 'EV Chakkarapani'],
#  9309: ['Julian Rivers', 'A J Rivers'],
#  9313: ['Deborah Wilson', 'D.J Wilson', 'Deborah J Wilson', 'DJ Wilson'],
#  9315: ['RL Sutton-Spence', 'Rachel L Sutton-Spence', 'R.L Sutton-Spence'],
#  17508: ['E G Clark', 'Gillian Clark', 'EG Clark'],
#  9318: ['Margaret Burke', 'Margaret A Burke', 'MA Burke', 'Margaret M Burke'],
#  9319: ['BGC Smith', 'Brendan G C Smith'],
#  9322: ['Martin Addy', 'M Addy'],
#  25707: ['Karen Elvers', 'KT Elvers', 'K T Elvers', 'Karen T Elvers'],
#  33901: ['Jill R Payne', 'J. Payne'],
#  1135: ['Duncan Grant', 'DA Grant'],
#  50289: ['Petros Mina'],
#  17522: ['Rita E M Langer', 'REM Langer'],
#  33908: ['Luigi Di Sarno'],
#  33911: ['T Isaacs', 'Talia Isaacs'],
#  33912: ['Chrissy L Hammond', 'C.L Hammond', 'CL Hammond'],
#  25721: ['IV Chenchiah', 'Isaac V. Chenchiah', 'Isaac Vikram Chenchiah'],
#  9340: ['GS Hogan-Brun'],
#  25725: ['Christopher R Melhuish',
#   'C. Melhuish',
#   'Christopher Melhuish',
#   'CR Melhuish'],
#  1152: ['SC Greer', 'Steven C Greer', 'S.C Greer'],
#  32960: ['H Sabir', 'Hemmen Sabir'],
#  25734: ['Lucy Hackshaw',
#   'Lucy  Hackshaw-McGeagh',
#   'Lucy E. Hackshaw',
#   'Lucy E Hackshaw'],
#  9353: ['PJ Roberts'],
#  58509: ['Kevin Smyth'],
#  17552: ['E Ibraim', 'Erdin Ibraim', 'E. Ibraim'],
#  25745: ["JL O'Brien",
#   "Jeremy L O'Brien",
#   "J L O'Brien",
#   "J.L O'Brien",
#   "Jeremy L. O'Brien",
#   "Jeremy O'Brien",
#   "J. L. O'Brien"],
#  1170: ['Paul A Grout', 'P.A Grout', 'PA Grout'],
#  1172: ['T. J. Gruffydd-Jones',
#   'T Gruffydd-Jones',
#   'TJ Gruffydd-Jones',
#   'Timothy J Gruffydd-Jones'],
#  17557: ['AM Joyce'],
#  17563: ['Gerard J. Van den Berg',
#   'Gerard Van den Berg',
#   'Gerard J. Van Den Berg',
#   'Gerard J. van den Berg'],
#  1186: ['P Haggett', 'Peter Haggett'],
#  33956: ['Harriet L. Mills', 'H. L. Mills', 'Harriet L Mills', 'H L Mills'],
#  33958: ['Victoria Sgardoni'],
#  1191: ['AP Halestrap',
#   'A.P Halestrap',
#   'Andrew Philip Halestrap',
#   'Andrew P. Halestrap',
#   'A. P. Halestrap',
#   'Andrew P Halestrap'],
#  17576: ['Anthony  Feiler',
#   'Anthony Feiler',
#   'A.C Feiler',
#   'AC Feiler',
#   'Anthony C Feiler'],
#  50346: ['Peter S Turner', 'Peter S. Turner', 'P. S. Turner'],
#  33964: ['Nick Simpson'],
#  15218: ['Sherif A Abdel-Fattah', 'Sherif Abdel-Fattah', 'S. Abdel-Fattah'],
#  33968: ['Christina Wei', 'C Wei'],
#  33973: ['E Mellios', 'Evangelos Mellios'],
#  9398: ['Michael Tierney',
#   'Michael J. Tierney',
#   'MJ Tierney',
#   'Michael J Tierney',
#   'M. J. Tierney'],
#  25785: ['P. Jiang', 'Pisu Jiang', 'P Jiang'],
#  33982: ['Raina Ramnath', 'Raina D Ramnath'],
#  9408: ['J.G Eastoe',
#   'JG Eastoe',
#   'Julian  Eastoe',
#   'Julian G Eastoe',
#   'Julian Eastoe'],
#  33985: ['OJ Benjamin'],
#  50370: ['Charlie R Beil'],
#  17604: ['Tamar Hodos', 'T Hodos'],
#  1225: ['JH Hannay', 'J. H. Hannay'],
#  33998: ['Jessica M Harris', 'Jessica Harris', 'J M Harris'],
#  7679: ['Catherine R Coates'],
#  17624: ['Ruth Glynn', 'RS Glynn'],
#  25817: ['S. Harding'],
#  25818: ['Avon Huxor', 'A. P. Huxor', 'A. Huxor', 'A.P Huxor'],
#  25819: ['Adrian G Flint', 'AG Flint'],
#  25822: ['K. V. Tennant', 'KV Tennant', 'Kathleen V Tennant', 'K V Tennant'],
#  17631: ['R Deem'],
#  66786: ['Jamie F. Lawson', 'J F Lawson'],
#  9443: ['S.G Burston', 'SG Burston', 'Steven G Burston'],
#  1252: ['Andrew J L Harrison', 'A. J. L. Harrison', 'AJL Harrison'],
#  1257: ['Richard Harrison'],
#  58603: ['Lisa van Dijk'],
#  25836: ['Sheila M Ellwood', 'SM Ellwood', 'S.M Ellwood'],
#  1261: ['Stephen A. Harris',
#   'Stephen S Harris',
#   'S Harris',
#   'Stephen Harris',
#   'Stephen  Harris'],
#  17653: ['J. D. Booker',
#   'Julian D Booker',
#   'JD Booker',
#   'Julian David Booker'],
#  17654: ['E T Jones', 'ET Jones', 'E.T Jones', 'Evan T Jones', 'Evan Jones'],
#  17656: ['LM McNally'],
#  17657: ['C Andrieu', 'Christophe Andrieu'],
#  25852: ['Tarnjit K. Khera', 'TK Khera', 'DE Szymkowski'],
#  17662: ['N.E Scott-Samuel',
#   'Nicholas E. Scott-Samuel',
#   'NE Scott-Samuel',
#   'Nicholas E Scott-Samuel'],
#  17665: ['Christopher P Benton', 'CP Benton'],
#  17666: ['S Volkov', 'Stanislav Volkov'],
#  52144: ['Nathan F Lepora', 'Nathan Lepora', 'Nathan F. Lepora'],
#  17669: ['Tom Diethe'],
#  10954: ['CA Williams', 'Caroline A Williams'],
#  17675: ["M.J O'Mahony", "MJ O'Mahony", "Mike J O'Mahony", "Mike O'Mahony"],
#  19330: ['Mike Crawford'],
#  34063: ['J R Pugh', 'J. R. Pugh', 'JR Pugh', 'Jon R Pugh'],
#  17681: ['LS Morrison'],
#  1302: ['P M Headley', 'PM Headley'],
#  9495: ['Craig A McArdle',
#   'C A McArdle',
#   'C.A McArdle',
#   'CA McArdle',
#   'Craig McArdle',
#   'Craig A. McArdle',
#   'Craig Alexander McArdle'],
#  9498: ['Linda P. Hunt', 'LP Hunt', 'Linda Hunt', 'Linda P Hunt'],
#  25883: ['Dave J Kilbey'],
#  1309: ['Alan J Hedges', 'AJ Hedges'],
#  17694: ['Lesel Dawson', 'LD Dawson'],
#  17695: ['Sean A Rands', 'SA Rands'],
#  17697: ['Stephen Bann'],
#  1317: ['D. L. Henshaw', 'Denis L Henshaw', 'Denis L. Henshaw'],
#  17706: ['SJ Hales', 'Shelley J Hales'],
#  1323: ['VM Hewitt'],
#  30258: ['Richard Sisson'],
#  1331: ['DJ Hicks'],
#  17724: ['Jim Spencer', 'J Spencer'],
#  25920: ['K van Aelst', 'Kara van Aelst'],
#  25921: ['J Goldstein', 'Joel Goldstein'],
#  25924: ['Jane Wright', 'JE Wright', 'Jane E Wright'],
#  7483: ['Rosemary Greenwood', 'R Greenwood', 'R.J Greenwood'],
#  17735: ['R. Huxtable', 'R Huxtable', 'Richard Huxtable'],
#  1352: ['JD Hill', 'Jonathan D Hill', 'J.D Hill'],
#  27532: ['D.L Watson', 'DL Watson', 'Debbie L Watson'],
#  25930: ['Anna C Bibby'],
#  25938: ['K. Hazra', 'K Hazra', 'Kalyan Hazra'],
#  50525: ['S. Friedemann', 'Sven Friedemann'],
#  34142: ['Andy L Skinner', 'Andrew L Skinner', 'AL Skinner'],
#  25956: ['J.W Pomeroy',
#   'James W. Pomeroy',
#   'James W Pomeroy',
#   'JW Pomeroy',
#   'J. W. Pomeroy',
#   'J. Pomeroy'],
#  58725: ['Emma Solomon'],
#  12519: ['NACS Wong'],
#  27538: ['S Dias', 'Sofia Dias', 'S. Dias'],
#  34158: ['Stephan Lautenschlager'],
#  31689: ['Kate M Mitchell'],
#  17779: ['J K H Hoerber', 'JKH H\\00F6rber'],
#  25973: ['Alan Whone', 'AL Whone', 'Alan L Whone', 'A Whone', 'A L Whone'],
#  1399: ['PE Holt'],
#  25976: ['P.G Dunton', 'PG Dunton', 'Peter G. Dunton'],
#  25977: ['R. S. Hogg'],
#  17791: ['M. Sieber', 'MMA Sieber', 'Martin M A Sieber'],
#  66947: ['S. A F Buijs', 'S. Buijs', 'Stephanie Buijs'],
#  1412: ['Susan M Hooper', 'SM Hooper', 'S. M. Hooper'],
#  25989: ['F.J Romero Salvado', 'FJ Romero Salvado', 'F J Romero Salvado'],
#  1414: ['DW Hopkins'],
#  9609: ['R Little'],
#  17804: ['M Li', 'Mei Li'],
#  34190: ['Shelby E Temple', 'S.E Temple', 'SE Temple'],
#  9615: ['Christina Pantazis', 'C Pantazis'],
#  34192: ['J. P H Belnoue',
#   'Jonathan Belnoue',
#   'J. Belnoue',
#   'J. P. Belnoue',
#   'Jonathan P. Belnoue'],
#  1425: ['Debi J Ford'],
#  17811: ['PH Mellor', 'P. H. Mellor', 'Phil H. Mellor', 'Phil Mellor'],
#  9620: ['P Emmett',
#   'PM Emmett',
#   'P M Emmett',
#   'Pauline Emmett',
#   'P. Emmett',
#   'Pauline M Emmett',
#   'Pauline M. Emmett'],
#  9621: ['DJ Gunnell',
#   'D. J. Gunnell',
#   'David Gunnell',
#   'D Gunnell',
#   'David J. Gunnell',
#   'D. Gunnell'],
#  34199: ['M Pieraccini', 'Margherita Pieraccini'],
#  9624: ['J P Hamilton-Shield',
#   'Julian P Hamilton-Shield',
#   'Julian Hamilton-Shield',
#   'J P Shield',
#   'JPH Shield'],
#  26009: ['Tamsin L Edwards', 'TL Edwards', 'Tamsin L. Edwards'],
#  9626: ['C N Canagarajah',
#   'N Canagarajah',
#   'Canagarajah Nishan',
#   'CN Canagarajah',
#   'Nishan Canagarajah',
#   'C Canagarajah',
#   'C. N. Canagarajah'],
#  34203: ['D. C. Barrett', 'DC Barrett', 'David C. Barrett', 'David C Barrett'],
#  17821: ['Helen L Winton'],
#  17825: ['Liang-Fong Wong', 'LF Wong', 'Liang Fong-Wong'],
#  58950: ['Christy Burden'],
#  9638: ['John Moran', 'JM Moran'],
#  34215: ['Cassie Newland'],
#  34216: ['Nadia Aghtaie', 'N Aghtaie'],
#  34217: ['Megan Blomfield'],
#  34218: ['EGM van Klink', 'Ed G M van Klink', 'Ed van Klink'],
#  26027: ['S L Murden', 'Sherina L Murden'],
#  17837: ['A Zhok'],
#  26031: ['E Steinerte', 'Elina Steinerte'],
#  17840: ['Kelvyn Jones', 'K Jones'],
#  9649: ['Alasdair I. Houston',
#   'AI Houston',
#   'Alasdair I Houston',
#   'A.I Houston'],
#  34227: ['Diana L Santos Ferreira', 'DL Santos Ferreira'],
#  50612: ['Charlotte E. Boott'],
#  9654: ['Richard Tinsley', 'RC Tinsley'],
#  9655: ["Mary J O'Connell"],
#  67001: ['Safet HadziMuhamedovic'],
#  1466: ['Ronald E Hutton', 'RE Hutton', 'R.E Hutton'],
#  1467: ['L Huxley'],
#  17852: ['G Daniels', 'Geoffrey L Daniels'],
#  34240: ['Christina L Maslen'],
#  50625: ['Imke Sittel'],
#  17859: ['Stephen R. Hallett',
#   'S. R. Hallett',
#   'S.R Hallett',
#   'Stephen Hallett',
#   'SR Hallett',
#   'Stephen R Hallett'],
#  9668: ['R. P. Evershed',
#   'Richard P Evershed',
#   'Richard Evershed',
#   'R.P Evershed',
#   'RP Evershed',
#   'Richard P. Evershed'],
#  26055: ['Catherine Hindson', 'Catherine E Hindson'],
#  9672: ['D. J E Elder', 'Douglas J E Elder'],
#  26059: ['Paula Giliker', 'P Giliker'],
#  26060: ['NR Ingram', 'Neil R Ingram'],
#  58832: ['Michael S. Tivers',
#   'Michael S Tivers',
#   'M S Tivers',
#   'Mickey Tivers',
#   'Michael Tivers',
#   'M. S. Tivers'],
#  9681: ['Sara T. Brookes', 'S Brookes', 'Sara T Brookes', 'S. T. Brookes'],
#  34258: ['Daniel J. Whitcomb', 'Daniel J Whitcomb', 'D Whitcomb'],
#  34259: ['P E Jessiman', 'T Jessiman', 'Tricia Jessiman'],
#  10961: ['Jonathan M Robbins', 'JM Robbins', 'J. M. Robbins'],
#  1503: ['DE Jane', 'David Jane', 'D. E. Jane', 'D.E Jane', 'David E Jane'],
#  17896: ['Paul G. Lawrence'],
#  17897: ['Nina C Snaith', 'NC Snaith'],
#  2983: ['LM Ward'],
#  26095: ['CSG Blakey'],
#  58963: ['He Sun'],
#  53502: ['Sebastiaan Verweij'],
#  9719: ['J Pickard', 'John Pickard'],
#  34296: ['M Voliotis', 'Margaritis Voliotis'],
#  34299: ['Zidong Zhao'],
#  17916: ['Rachael J S Gooberman-Hill',
#   'Rachael Gooberman-Hill',
#   'RJS Gooberman-Hill'],
#  43946: ['Anna Tzanakaki', 'A. Tzanakaki'],
#  34303: ['J W Yeates',
#   'J. Yeates',
#   'James Yeates',
#   'James W Yeates',
#   'JW Yeates'],
#  33024: ['Byung Chul (Eric) Kim', 'Byung Chul Kim'],
#  9733: ['Robert J Pope', 'RJP Pope', 'Robert J P Pope'],
#  26119: ['J Dourneen', 'Jean Dourneen'],
#  34316: ['Sarah E Greene', 'SE Greene'],
#  34317: ['M Pufulete', 'Maria Pufulete', 'Maria M Pufulete'],
#  9742: ['C Dayan',
#   'C. Dayan',
#   'Colin M. Dayan',
#   'CM Dayan',
#   'Colin M Dayan',
#   'C M Dayan',
#   'Colin Dayan',
#   'C. M. Dayan'],
#  17935: ['SM Thomas', 'S.M Thomas', 'Sally M Thomas', 'Salim Massoud'],
#  50704: ['Anastasia Koutsomitopoulou'],
#  17938: ['David Drury', 'D Drury'],
#  17940: ['JRW Temple',
#   'Jonathan R W Temple',
#   'J.R.W Temple',
#   'Jon R W Temple'],
#  26134: ['Caroline M Taylor'],
#  50711: ['O. J. Nixon-Pearson'],
#  50712: ['Saatviga Sudhahar'],
#  23471: ['SC Baos', 'S. C. Baos'],
#  26142: ['GM Russell'],
#  17951: ['Amanda Hall', 'Amanda J Hall', 'AJ Hall'],
#  34336: ['TY Dokchitser', 'Tim Dokchitser'],
#  11184: ['Christopher R Helps',
#   'CR Helps',
#   'C R Helps',
#   'Christopher Helps',
#   'C. R. Helps'],
#  1572: ['SP Jones'],
#  58921: ['T. O. Erinosho'],
#  58922: ['Emily L Porter'],
#  9776: ['G.C Seabourne', 'Gwen C Seabourne', 'GC Seabourne', 'Gwen Seabourne'],
#  34353: ['M B Cannell', 'C Soeller', 'Mark B Cannell', 'MB Cannell'],
#  27571: ['C Kent', 'Chris Kent'],
#  34361: ['K Williams', 'Katherine Williams'],
#  34399: ['Robert Carroll', 'R Carroll'],
#  35766: ['Shawanda N Stockfelt'],
#  1606: ['JR Kerridge'],
#  9801: ['Guy Nason', 'Guy P Nason', 'GP Nason'],
#  50762: ['Tamara Grava'],
#  34385: ['Kyle W. R. Taylor', 'Kyle Taylor', 'Kyle W R Taylor'],
#  34387: ['R.F Page', 'R. H. Page', 'Ryan F Page', 'R. F. Page'],
#  34391: ['Rick Bruintjes', 'R Bruintjes'],
#  67163: ['D.M. Mitchell', 'Dann M Mitchell', 'D. Mitchell'],
#  1631: ['Kirwan J R',
#   'J. R. Kirwan',
#   'John R. Kirwan',
#   'John R Kirwan',
#   'J. Kirwan',
#   'John Richard Kirwan',
#   'John Kirwan'],
#  9824: ['Geoffrey C Allen', 'Geoffrey C. Allen', 'GC Allen'],
#  26210: ['B. Buse', 'Benjamin Buse', 'B Buse'],
#  9828: ['CP Case', 'C.P Case', 'C P Case', 'Charles P Case', 'C Patrick Case'],
#  9829: ['In-Uck Park', 'I-U Park'],
#  9831: ['S. J. Hunter', 'Stephen Hunter'],
#  34410: ['Lorna J Duncan'],
#  26219: ['A. N. Radford',
#   'AN Radford',
#   'A.N Radford',
#   'Andy Radford',
#   'Andy N Radford'],
#  1645: ['JG Kyle', 'J.G Kyle', 'Jim G Kyle'],
#  26223: ['Maria Fannin', 'M Fannin'],
#  34416: ['Julie Williams'],
#  9842: ['FF Whitaker', 'Fiona Whitaker', 'Fiona F Whitaker'],
#  9844: ['PJ Heard', 'P J Heard', 'P.J Heard', 'Peter J Heard'],
#  26234: ['Dorothy C Rowe', 'Dorothy Price', 'DC Rowe'],
#  34428: ['Katharine V. Cashman',
#   'K V Cashman',
#   'KV Cashman',
#   'Katharine V Cashman',
#   'Katharine Cashman'],
#  18053: ['John Lyons', 'WJ Lyons', 'W J Lyons', 'W.J Lyons'],
#  9866: ['BT Stollery', 'Brian T Stollery'],
#  9837: ['Toity Deave', 'T Deave'],
#  1681: ['S N Lawson', 'Sally N. Lawson', 'Sally N Lawson'],
#  1682: ['CM Lazarus',
#   'Colin M. Lazarus',
#   'Colin M Lazarus',
#   'C Lazarus',
#   'C.M Lazarus'],
#  18068: ['J Sloman'],
#  9877: ['S. C. Kohn', 'Simon C. Kohn', 'SC Kohn', 'Simon C Kohn'],
#  26262: ['N Perez-Solorzano Borragan', 'Nieves Perez-Solorzano Borragan'],
#  27588: ['A Sayers',
#   'Adrian E Sayers',
#   'AE Sayers',
#   'Adrian Sayers',
#   'A. Sayers'],
#  34464: ['J. Verdon',
#   'J. P. Verdon',
#   'JP Verdon',
#   'James P. Verdon',
#   'James P Verdon',
#   'J P Verdon'],
#  9890: ['Julie  Selwyn',
#   'Julie T Selwyn',
#   'J.T Selwyn',
#   'JT Selwyn',
#   'Julie Selwyn'],
#  18083: ['H Goldstein', 'Harvey Goldstein'],
#  50852: ['James Kratz'],
#  18090: ['G Cameron'],
#  26284: ['AC Staubitz', 'Anne Staubitz'],
#  34418: ['C. Putzke'],
#  34484: ['Michael P Taylor', 'M. P. Taylor', 'Michael Taylor'],
#  1719: ['R.A Levitas', 'RA Levitas'],
#  7695: ['T Brown'],
#  18105: ['Katerina Michaelides', 'K Michaelides'],
#  26300: ['M. Adinolfi', 'Marco Adinolfi'],
#  26303: ['J. H. Rademacker',
#   'J. Rademacker',
#   'Jonas Rademacker',
#   'JH Rademacker',
#   'Jonas H Rademacker',
#   'J.H Rademacker'],
#  18113: ['RW Jones', 'Richard W Jones'],
#  34498: ['C. L. Relton',
#   'Caroline L. Relton',
#   'Caroline L Relton',
#   'Caroline Relton',
#   'C L Relton'],
#  26312: ['Lauren K Hughes', 'LK Hughes', 'L.K Hughes'],
#  34506: ['Timo C Hiller'],
#  18123: ['Robert J. Piechocki',
#   'RJ Piechocki',
#   'Robert J Piechocki',
#   'R. Piechocki',
#   'Robert Piechocki'],
#  33058: ['AF Baird',
#   'SD McKinnon',
#   'A F Baird',
#   'Alan F. Baird',
#   'A. F. Baird'],
#  1743: ['SJW Lisney'],
#  26324: ['K Barraclough'],
#  26325: ['OliphKenant Oliphant',
#   'Ken` Oliphant',
#   'K Oliphant',
#   'Ken Oliphant'],
#  26328: ['TR Gaunt', 'Tom R Gaunt', 'Tom R. Gaunt', 'T. Gaunt', 'Tom Gaunt'],
#  34521: ['Thorkild I. A. Sorensen'],
#  26330: ['Santi Rodriguez', 'S Rodr\\00EDguez', 'Santiago Rodriguez'],
#  9961: ['Colin J Pennycuick', 'CJ Pennycuick'],
#  18158: ['L. Dihoru', 'L Dihoru', 'Luiza Dihoru'],
#  26355: ['Alison Rust', 'Alison C Rust', 'A. C. Rust', 'AC Rust'],
#  26358: ["C.G O'Rawe", "CG O'Rawe", "Catherine O'Rawe", "Catherine G O'Rawe"],
#  67324: ['Christabelle Peters'],
#  50941: ['Luke J. Nelson', 'L. J. Nelson'],
#  67327: ['Sumita Mukherjee'],
#  18177: ['Wael Kafienah', 'W. Kafienah', 'W Kafienah'],
#  26371: ['Caroline Gardiner'],
#  34566: ['MR Challand', 'Martin R. Challand'],
#  9991: ['DJ Ashby'],
#  1800: ['Stephen R Lyne'],
#  26378: ['P. M. Taylor', 'P M Taylor', 'Polly M Taylor', 'PM Taylor'],
#  67342: ['Yohei Yamauchi'],
#  35800: ['Robert French', 'R French'],
#  22147: ['MC Fraser', 'Mike  Fraser', 'Mike Fraser', 'M.C Fraser'],
#  18197: ['Julie Townsend', 'J Townsend'],
#  34582: ['Paul A Wilkinson'],
#  34583: ['D. S. Ivanov', 'Dmitry Ivanov', 'D Ivanov', 'D. Ivanov'],
#  34584: ['M. Gradhand', 'Martin Gradhand'],
#  34586: ['Havi Carel', 'Havi H Carel'],
#  10013: ['Jeffrey Holly',
#   'LJ Vatten',
#   'JM Holly',
#   'JMP Holly',
#   'J M P Holly',
#   'Jeffrey M P Holly'],
#  59166: ['Armin Elsler'],
#  10972: ['Patricia A Kennett', 'PA Kennett'],
#  34598: ['Tolga N. V. Karsili'],
#  10024: ['JA Dudley'],
#  50985: ['Dominik Huelse'],
#  7759: ['Matthew Walker'],
#  34605: ['Maria Clara Restrepo-Mendez', 'M.C. Restrepo-M\\00E9ndez'],
#  47585: ['Madhu Krishnan'],
#  34607: ['Roxane Agnew-Davies'],
#  26420: ['C.A Whitnall', 'Carolyn A Whitnall'],
#  26425: ['Christopher J Woods',
#   'CJ Woods',
#   'Christopher J. Woods',
#   'Christopher Woods'],
#  607: ['T Cosgrove', 'T. Cosgrove', 'Terence Cosgrove'],
#  26427: ['Victoria K Morris', 'V. K. Morris', 'V Morris', 'V. Morris'],
#  51007: ['Gemma C Sharp'],
#  59202: ['Grace Huxford'],
#  18249: ['Christopher R Neal',
#   'Chris R. Neal',
#   'C. R. Neal',
#   'CR Neal',
#   'Chris R Neal'],
#  1866: ['CA Martindale'],
#  26446: ['Kate E Evans', 'KE Evans'],
#  1876: ['KJ Doogan'],
#  1881: ['Sarah E. Hewlett', 'S Hewlett', 'Sarah Hewlett', 'SE Hewlett'],
#  26459: ['George Iordanidis'],
#  67421: ['Angela M Brant'],
#  34660: ['D. Morton'],
#  1893: ['Rodney Lowe'],
#  10087: ['Christian B Allen',
#   'Christian B. Allen',
#   'C. Allen',
#   'Christian Allen',
#   'C.B Allen',
#   'CB Allen'],
#  33084: ['RAD Ramalho',
#   'R.A.S. Ramalho',
#   'R.S. Ramalho',
#   'Ricardo Ramalho',
#   'Ricardo S. Ramalho',
#   'R. Ramalho',
#   'R Ramalho'],
#  34666: ['Paul D. Smith'],
#  26480: ['V Cameron', 'Vyllinniskii Cameron'],
#  34675: ['Thorsten Wagener', 'T. Wagener'],
#  34676: ['Stefan G E Roberts', 'SGE Roberts'],
#  1909: ['B M Lumb', 'BM Lumb', 'Bridget M Lumb', 'B. M. Lumb'],
#  1911: ['John G Marshall'],
#  18299: ['Hongyu Li', 'H Li'],
#  1917: ['T. Martin',
#   'Trevor P Martin',
#   'T.P. Martin',
#   'TP Martin',
#   'T P Martin',
#   'T. P. Martin'],
#  26261: ['H Gersen', 'H. Gersen', 'Henkjan Gersen'],
#  10113: ['JB Uney', 'James B Uney', 'J.B Uney'],
#  23531: ['M. D. Wright', 'Matthew D. Wright'],
#  26500: ['Dheeraj Rai', 'D Rai'],
#  1927: ['B Matthews'],
#  18317: ['L Duffy'],
#  18319: ['Trevor D B Thompson', 'T Thompson'],
#  34705: ['AP Limmack'],
#  34706: ['Hannah J Maple', 'Hannah J. Maple'],
#  18325: ['Graham Bayly'],
#  10137: ['R. Leo Brady', 'R. L. Brady', 'RL Brady', 'R.L Brady', 'R L Brady'],
#  18330: ['Fiona E. Fox', 'Fiona Fox', 'Fiona E Fox', 'F E Fox'],
#  18332: ['Stephen R Wiggins', 'S Wiggins', 'Stephen Wiggins'],
#  26526: ['Neil Davies',
#   'Neil M. Davies',
#   'Neil M Davies',
#   'NM Davies',
#   'N.M Davies'],
#  10145: ['N Dahnoun', 'Naim Dahnoun'],
#  34722: ['Andrea Chidichimo'],
#  1955: ['J.P McGeehan',
#   'Joe P. McGeehan',
#   'Joe McGeehan',
#   'Joe P McGeehan',
#   'J. P. McGeehan',
#   'J. McGeehan',
#   'JP McGeehan'],
#  34728: ['James Hillier'],
#  18345: ['Emma Hitchings', 'E Hitchings'],
#  18346: ['J McLellan', 'Josie McLellan'],
#  10155: ['K. Papasouliotis',
#   'KP Papasouliotis',
#   'K Papasouliotis',
#   'Kostas Papasouliotis'],
#  34734: ['A Cammarano', 'Andrea Cammarano'],
#  26544: ['AR Booker', 'Andrew R Booker'],
#  34738: ['Gemma Lasseter', 'Gemma M Lasseter', 'G Lasseter', 'G M Lasseter'],
#  26549: ['A Volianskis', 'Arturas Volianskis'],
#  34742: ['FE Carroll', 'Fran E Carroll'],
#  1976: ['S Meadows', 'S.A.C Meadows'],
#  14593: ['S Kupzig', 'Sabine Kupzig'],
#  5791: ['Keith R Hallam', 'Keith Richard Hallam', 'KR Hallam'],
#  26556: ['Tom J Curry', 'TJ Curry'],
#  65866: ['Rachel Cohen'],
#  10174: ['David Dymock', 'D Dymock'],
#  18368: ['I.M. Howat',
#   'Anthony J. Payne',
#   'Antony J. Payne',
#   'A. J. Payne',
#   'A J Payne',
#   'AJ Payne'],
#  10180: ['Karen Duncan', 'K Duncan'],
#  67525: ['Esther Walton'],
#  18378: ['Sadie C Slater', 'S Slater'],
#  34763: ['Charlotte E M Lloyd', 'CEM Lloyd'],
#  34764: ['Simon M Bryant'],
#  1997: ['Roger Middleton', 'R Middleton'],
#  24344: ['Morgan Bronwen', 'Bronwen M Morgan'],
#  18383: ['A Lopez Bernal', 'Andres Lopez Bernal'],
#  34768: ['Alison L Williams'],
#  34769: ['Claire L Shaw', 'CL Shaw'],
#  26583: ['Stephen Gray', 'Stephen R Gray', 'SR Gray'],
#  34778: ['Augusto Penna'],
#  26592: ['Virginia C Gould', 'VC Gould'],
#  10211: ['S Li'],
#  26597: ['N.A Jackson', 'Nikki A Sawyer'],
#  26598: ['Lucy Beasant'],
#  51186: ['I. F. Lazar'],
#  34809: ['Simon J Potter', 'S Potter'],
#  34812: ['James Hickey'],
#  18429: ['Dhiraj K. Pradhan',
#   'Dhiraj Pradhan',
#   'Pradhan Dhiraj',
#   'Dhiraj K Pradhan',
#   'D. K. Pradhan',
#   'DK Pradhan'],
#  26622: ['Esther Crawley',
#   'EM Crawley',
#   'Esther M Crawley',
#   'Esther M. Crawley',
#   'E Crawley'],
#  34816: ['Amanda J Burridge'],
#  34819: ['Jessica  Smyth'],
#  34820: ['Andrew J Simpkin'],
#  2056: ['K.M Moreton'],
#  10249: ['G Tilly'],
#  2058: ['AJ Morgan'],
#  26637: ['SH Gage', 'Suzanne H. Gage', 'Suzanne H Gage'],
#  34833: ['Jessica Gwyther', 'J Gwyther'],
#  34834: ['Richard C Bond'],
#  34835: ['E N Barker',
#   'Emily N. Barker',
#   'E. Barker',
#   'E. N. Barker',
#   'EN Barker',
#   'Emily N Barker'],
#  18454: ['AE Pickering',
#   'A. E. Pickering',
#   'A E Pickering',
#   'Anthony E. Pickering'],
#  18457: ['Andrei Sarua', 'A. Sarua', 'A Sarua'],
#  26650: ['M Albur', 'Mahableshwar S Albur'],
#  26651: ['Elizabeth M Hill'],
#  26652: ['JC Rougier', 'Jonathan C Rougier', 'J. C. Rougier'],
#  51230: ['Duncan R Boa'],
#  34850: ['Rowan C Tomlinson', 'R.C Tomlinson'],
#  2084: ['RT Moses'],
#  26802: ['Davi A W Barton',
#   'David A W Barton',
#   'DAW Barton',
#   'D A W Barton',
#   'D. A. W. Barton',
#   'David A. W. Barton'],
#  18472: ['Nadia Cerminara', 'Nadia L Cerminara', 'NL Cerminara'],
#  18475: ['T M D Kovacs', 'Tim Kovacs', 'TMD Kovacs'],
#  34863: ['E Stergiakouli', 'Evangelia Stergiakouli'],
#  59442: ['Aaron G Lim'],
#  29803: ['A Fraser', 'Abigail Fraser'],
#  12638: ['Zuner A. Bortolotto',
#   'ZA Bortolotto',
#   'Zuner Bortolotto',
#   'Zuner A Bortolotto'],
#  26678: ['KE Ranaghan', 'Kara E. Ranaghan', 'Kara E Ranaghan'],
#  59447: ['Emily Coit'],
#  59448: ['Robert Julio Decker'],
#  9908: ['N. Claydon',
#   'Nicholas Claydon',
#   'N C A Claydon',
#   'N. C. A. Claydon',
#   'NCA Claydon'],
#  10300: ['M.D Szczelkun', 'MD Szczelkun', 'Mark D Szczelkun'],
#  2111: ['Martin Murray', 'M Murray', 'M. Murray'],
#  2112: ['JH Musgrave'],
#  33120: ['Tom G Richardson'],
#  18501: ['S. G. Siddell', 'SG Siddell', 'Stuart G Siddell'],
#  18502: ['PJ Strachan'],
#  2119: ['David F T Nash', 'DFT Nash'],
#  35852: ['Thomas Lansdall-Welfare'],
#  26698: ['SR Grant', 'Simon Grant'],
#  34893: ['Esther Tanja Kok', 'Esther T Kok'],
#  34897: ['Marianna R Dudley', 'M Dudley'],
#  2131: ['GW Neilson'],
#  18516: ['Daniel Page'],
#  10327: ['R. A. Brooker', 'R A Brooker', 'Richard A. Brooker', 'RA Brooker'],
#  2136: ['PV Newcomb'],
#  26720: ['S. Jacobs'],
#  59492: ['Zo\\00EB Ward', 'Zo\\00EB D Ward'],
#  65894: ['Imogen Richens'],
#  34918: ['MLP Harris'],
#  34919: ['Jon James', 'JP James'],
#  34920: ['JCF Matthews',
#   'Jonathan C. F. Matthews',
#   'Jonathan C F Matthews',
#   'J.C.F Matthews',
#   'J. C. F. Matthews',
#   'Jonathan Matthews',
#   'J C F Matthews'],
#  10348: ['Jonathan Lawry', 'J Lawry'],
#  10350: ['Marianne Hester', 'M Hester'],
#  18543: ['SJ Friederich'],
#  18544: ['OL Quick', 'O.L Quick', 'Oliver L Quick'],
#  18545: ['Jonathan P Burnside', '.J.P Burnside', 'JP Burnside'],
#  22206: ['Sarah J. Lewis', 'Sarah J Lewis', 'SJ Lewis'],
#  26743: ['T Burghardt', 'Tilo Burghardt'],
#  34937: ['Robin M Neville'],
#  2170: ['J. F. Nye'],
#  18555: ['WC Yee', 'Wan Ching Yee', 'W.C Yee'],
#  18557: ['SP Gregory'],
#  26750: ['E Szilassy', 'Eszter Szilassy'],
#  2175: ['Derek C Offord', 'Derek Offord', 'DC Offord', 'D.C Offord'],
#  59521: ['Tara Puri'],
#  59522: ['Benjamin Pohl'],
#  26761: ['Alexander Farnsworth'],
#  34954: ['Derek R Laver'],
#  2188: ['AG Orpen', 'A. G. Orpen', 'A. Guy Orpen', 'A G Orpen', 'A.G Orpen'],
#  18573: ['Suzanne Audrey', 'S Audrey'],
#  26774: ['D Dickenson'],
#  18583: ['Clare L Emmett', 'CL Emmett', 'Clare Thomas'],
#  51352: ['Barry K Carpenter'],
#  18585: ['Andrew L Lux', 'AL Lux', 'Andrew Lux'],
#  26781: ['Ben Sessa'],
#  34974: ['T. Gross', 'Thilo Gross', 'T Gross'],
#  67744: ['M. D. Bennett', 'Mark D. Bennett', 'Mark David Bennett'],
#  35867: ['Christoph W\\00FClfing'],
#  34982: ['A. Simpson'],
#  26792: ['C. A. Jepson', 'K.A Jepson'],
#  19484: ['Guobing Lu', 'G Lu'],
#  5831: ['John Crosby', 'J Crosby'],
#  2223: ['Christos Paraskeva', 'C Paraskeva'],
#  18608: ['F.R Manby',
#   'Frederick R Manby',
#   'FR Manby',
#   'F. R. Manby',
#   'Frederick R. Manby'],
#  26801: ['Paul Verkade', 'P Verkade'],
#  18610: ['MCG Stevens', 'Mike C G Stevens', 'M C G Stevens'],
#  10420: ['David J. Evans'],
#  18614: ['St\\00E9phanie Pellegrin', 'S Pellegrin', 'Stephanie Pellegrin'],
#  13986: ['Alison S Bienemann',
#   'Ali S Bienemann',
#   'Ali Bienemann',
#   'AS Bienemann'],
#  2232: ['John Parkin', 'J Parkin'],
#  26811: ['MJ Ailes', 'Marianne J Ailes'],
#  18622: ['David O Hall'],
#  18624: ['Begonia Morales-Aza'],
#  35010: ['C Raistrick'],
#  35011: ['Emer Brangan'],
#  18631: ['Pete Walker'],
#  10441: ['P. E J Flewitt',
#   'PEJ Flewitt',
#   'Peter E. J. Flewitt',
#   'P. E. J. Flewitt',
#   'Peter E J Flewitt'],
#  35018: ['Bethan R Hawley'],
#  51403: ['Kellie Snow'],
#  18637: ['Tim Williams', 'Tim M. Williams', 'TM Williams', 'Tim M Williams'],
#  26830: ['Hannah Tayler', 'Hannah M Tayler', 'Hannah M. Tayler', 'HM Tayler'],
#  26831: ['Thea K Hincks', 'T. K. Hincks', 'TK Hincks'],
#  26834: ['Christoph Schwitzer'],
#  10451: ['ID Learmonth'],
#  10452: ['D. J. Sharp',
#   'Debbie J Sharp',
#   'Debbie Sharp',
#   'D J Sharp',
#   'D Sharp'],
#  35032: ['C.C Ioannou',
#   'C. C. Ioannou',
#   'CC Ioannou',
#   'Christos C. Ioannou',
#   'Christos C Ioannou'],
#  51417: ['Tom Walker'],
#  35034: ['Beverley A De Valois'],
#  18651: ['James Thompson', 'J Thompson'],
#  10461: ['Derek N. Woolfson',
#   'Dek N Woolfson',
#   'Dek Woolfson',
#   'D.N Woolfson',
#   'DN Woolfson',
#   'D. N. Woolfson',
#   'Derek N Woolfson'],
#  26846: ['CJ Thorogood', 'C. J. Thorogood'],
#  52261: ['Susana Almeida'],
#  26848: ['M A Caldwell',
#   'MA Caldwell',
#   'Maeve A. Caldwell',
#   'Maeve A Caldwell'],
#  379: ['RGA Buxton', 'Richard G A Buxton', 'R.G.A Buxton'],
#  22383: ['R. J. Edwards', 'RJ Edwards', 'Richard J Edwards', 'R J Edwards'],
#  59622: ['C. Jill Harrison', 'C Jill Harrison'],
#  59624: ['Edward Holberton'],
#  2281: ['GR Pearson'],
#  27687: ['Christie L Cabral', 'C Cabral', 'Cabral Christie'],
#  26861: ['JA Vicary', 'James A Vicary', 'J.A Vicary'],
#  6350: ['R A Persad', 'R Persad', 'Rajendra A Persad', 'R.A Persad'],
#  18678: ['Michael Jackson'],
#  35063: ['X Yuan', 'Xibo Yuan'],
#  35064: ['C Warren-Smith', 'Chris Warren-Smith', 'C. M R Warren-Smith'],
#  67284: ['S. Alexander'],
#  10494: ['Michael R Norman', 'MR Norman'],
#  18133: ['Angela A Piccini', 'AA Piccini'],
#  10497: ['A.J Bennett', 'Andrew  Bennett', 'AJ Bennett'],
#  18690: ['Edward J. A. Drewitt', 'EJA Drewitt'],
#  26884: ['E.C Hornby', 'Emma C Hornby', 'EC Hornby'],
#  26886: ['TD Wooley', 'T. D. Wooley', 'Trevor D Wooley', 'Trevor D. Wooley'],
#  51464: ['Hilary M Carey', 'Hilary M. Carey', 'Hilary Carey'],
#  18697: ['D Robert', 'Daniel Robert', 'D. Robert'],
#  26892: ['Anna E Long', 'Anna Long', 'AE Long'],
#  12674: ['Y. Ben-Shlomo', 'Y Ben-Shlomo', 'Yoav Ben-Shlomo'],
#  59663: ['Gordon N Inglis'],
#  59664: ['A D Warren'],
#  18136: ['R.E Deakin Crick', 'RE Deakin Crick', 'Ruth E Deakin Crick'],
#  2322: ['Brian T Pickering'],
#  34175: ['Jennifer Greenwood'],
#  10516: ['A. D. Putter', 'Ad Putter', 'A Putter'],
#  35094: ['Cherrie H T Kong', 'Cherrie Kong', 'H T Kong'],
#  26907: ['A J Ridgwell',
#   'A. J. Ridgwell',
#   'AJ Ridgwell',
#   'Andy J. Ridgwell',
#   'Andy Ridgwell',
#   'A. Ridgwell',
#   'Andy J Ridgwell',
#   'A.J Ridgwell'],
#  26908: ['W. J. Browne',
#   'William J Browne',
#   'WJ Browne',
#   'W.J Browne',
#   'William J. Browne'],
#  35103: ['Andrew J P Flack', 'Andy J P Flack'],
#  35104: ['J. F. Graham'],
#  2337: ['CM Sellen'],
#  43299: ['M. Duleeka W Knipe', 'Dee Perera', 'Dee Knipe'],
#  2341: ['BR Pollard'],
#  2342: ['Jonathan I Pollock'],
#  59688: ['Andrea Tassi'],
#  10538: ['LS Bibbings', 'L.S Bibbings'],
#  43307: ['Lucy E G Donkin'],
#  18734: ['Michael Rudnev', 'M Rudnev'],
#  35119: ['Sarah Westbury', 'Sarah K Westbury'],
#  35123: ['David J Manley', 'DJ Manley', 'M van Ham'],
#  35124: ['Lars Rudolf', 'L Rudolf'],
#  51509: ['D. C. Stanier'],
#  35126: ['Gergely Czel', 'G. Czel'],
#  ...}

# %% [markdown]
# ## `staff` ##

# %%
# Remove TYPE (all are staff)
# Remove START_DATE and END_DATE
del staff["TYPE"]
del staff["START_DATE"]
del staff["END_DATE"]

# %%
staff = staff.sort_values("PERSON_ID", axis=0)

# %%
staff_pid = list(set(staff["PERSON_ID"].values))

# %%
# Check author_ids is a subset of staff_ids
for i in auth_pids:
    if i not in staff_pid:
        print "Person %d not in staff record" % i

# %%
new_staff_record = []
for i in staff_pid:
    staff_row = staff[staff["PERSON_ID"]==i]
    j = {}
    j["PERSON_ID"] = i
    j["PUBLISHED_NAME"] =  list(set( list(set(staff_row["PUBLISHED_NAME"].values)) + auth_pn[i]  )) # add published name
    j["FORENAME"] = list(set(staff_row["FORENAME"].values))
    j["SURNAME"] = list(set(staff_row["SURNAME"].values))
    j["ORGANISATION_CODE"] = list(set(staff_row["ORGANISATION_CODE"].values))
    j["JOB_TITLE"] = list(set(staff_row["JOB_TITLE"].values))
    new_staff_record.append(j)

# %%
staff_record = pd.DataFrame(new_staff_record)

# %%
staff_record.index = staff_record["PERSON_ID"].values
del staff_record["PERSON_ID"]

# %%
# reorder columns
staff_record = staff_record[["FORENAME", "SURNAME", "PUBLISHED_NAME", "JOB_TITLE", "ORGANISATION_CODE"]]

# %%
# Each person should only have one FORENAME and one SURNAME
for i, row in staff_record.iterrows():
    if len(row["FORENAME"]) != 1:
        print "Two names: %d" % i
    if len(row["SURNAME"]) != 1:
        print "Two surnames: %d" % i
    if len(row["PUBLISHED_NAME"]) != 1:
        print "More than one published names: %d" % i
    if len(row["JOB_TITLE"]) != 1:
        print "More than one job title: %d" % i
    if len(row["ORGANISATION_CODE"]) != 1:
        print "More than one organisation code: %d" % i
    print "----------+++++++++++++--------------"
# Out:
# More than one published names: 24576
# More than one job title: 24576
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 24581
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 24586
# ----------+++++++++++++--------------
# More than one published names: 16395
# ----------+++++++++++++--------------
# More than one published names: 49164
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 16403
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 24601
# ----------+++++++++++++--------------
# More than one published names: 16410
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 33
# ----------+++++++++++++--------------
# More than one published names: 8227
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 32811
# ----------+++++++++++++--------------
# More than one job title: 44
# More than one organisation code: 44
# ----------+++++++++++++--------------
# More than one published names: 24621
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 24627
# ----------+++++++++++++--------------
# More than one published names: 16436
# ----------+++++++++++++--------------
# More than one published names: 16438
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 24638
# ----------+++++++++++++--------------
# More than one published names: 43701
# ----------+++++++++++++--------------
# More than one published names: 16448
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 49222
# ----------+++++++++++++--------------
# More than one published names: 49224
# ----------+++++++++++++--------------
# More than one published names: 77
# ----------+++++++++++++--------------
# More than one published names: 49230
# ----------+++++++++++++--------------
# More than one published names: 32848
# ----------+++++++++++++--------------
# More than one published names: 16465
# ----------+++++++++++++--------------
# More than one published names: 83
# ----------+++++++++++++--------------
# More than one published names: 8277
# ----------+++++++++++++--------------
# More than one published names: 8278
# More than one job title: 8278
# More than one organisation code: 8278
# ----------+++++++++++++--------------
# More than one published names: 16471
# ----------+++++++++++++--------------
# More than one published names: 24665
# ----------+++++++++++++--------------
# More than one published names: 94
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 8288
# ----------+++++++++++++--------------
# More than one published names: 32866
# ----------+++++++++++++--------------
# More than one published names: 24677
# More than one organisation code: 24677
# ----------+++++++++++++--------------
# More than one published names: 24678
# ----------+++++++++++++--------------
# More than one published names: 103
# ----------+++++++++++++--------------
# More than one published names: 104
# ----------+++++++++++++--------------
# More than one published names: 105
# ----------+++++++++++++--------------
# More than one published names: 24683
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 16500
# ----------+++++++++++++--------------
# More than one published names: 34920
# ----------+++++++++++++--------------
# More than one published names: 16511
# More than one job title: 16511
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 32899
# ----------+++++++++++++--------------
# More than one published names: 132
# ----------+++++++++++++--------------
# More than one published names: 36886
# ----------+++++++++++++--------------
# More than one published names: 24710
# ----------+++++++++++++--------------
# More than one published names: 16525
# ----------+++++++++++++--------------
# More than one published names: 32910
# ----------+++++++++++++--------------
# More than one published names: 24721
# ----------+++++++++++++--------------
# More than one published names: 24724
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 49303
# More than one job title: 49303
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 8346
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 57512
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 32942
# ----------+++++++++++++--------------
# More than one published names: 32943
# ----------+++++++++++++--------------
# More than one published names: 25920
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 178
# ----------+++++++++++++--------------
# More than one published names: 16565
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 185
# ----------+++++++++++++--------------
# More than one published names: 189
# ----------+++++++++++++--------------
# More than one published names: 34165
# ----------+++++++++++++--------------
# More than one published names: 24768
# ----------+++++++++++++--------------
# More than one published names: 193
# ----------+++++++++++++--------------
# More than one published names: 14191
# ----------+++++++++++++--------------
# More than one published names: 32964
# More than one job title: 32964
# More than one organisation code: 32964
# ----------+++++++++++++--------------
# More than one published names: 30070
# ----------+++++++++++++--------------
# More than one published names: 8225
# More than one job title: 8225
# ----------+++++++++++++--------------
# More than one published names: 204
# More than one job title: 204
# ----------+++++++++++++--------------
# More than one published names: 25921
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 32979
# ----------+++++++++++++--------------
# More than one published names: 16596
# ----------+++++++++++++--------------
# More than one published names: 24792
# More than one job title: 24792
# ----------+++++++++++++--------------
# More than one published names: 47824
# ----------+++++++++++++--------------
# More than one published names: 8421
# ----------+++++++++++++--------------
# More than one published names: 16615
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 238
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 16626
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one job title: 8441
# More than one organisation code: 8441
# ----------+++++++++++++--------------
# More than one published names: 25983
# More than one job title: 25983
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 8448
# ----------+++++++++++++--------------
# More than one published names: 28715
# ----------+++++++++++++--------------
# More than one published names: 33029
# More than one job title: 33029
# More than one organisation code: 33029
# ----------+++++++++++++--------------
# More than one published names: 16647
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 15063
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 33044
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 8482
# ----------+++++++++++++--------------
# More than one published names: 12337
# ----------+++++++++++++--------------
# More than one published names: 33064
# ----------+++++++++++++--------------
# More than one published names: 27356
# ----------+++++++++++++--------------
# More than one published names: 302
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 16690
# ----------+++++++++++++--------------
# More than one published names: 49203
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 43742
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 32820
# ----------+++++++++++++--------------
# More than one published names: 315
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 24898
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 330
# ----------+++++++++++++--------------
# More than one published names: 16715
# ----------+++++++++++++--------------
# More than one published names: 49486
# ----------+++++++++++++--------------
# More than one published names: 16720
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 24914
# ----------+++++++++++++--------------
# More than one published names: 35555
# ----------+++++++++++++--------------
# More than one published names: 35473
# ----------+++++++++++++--------------
# More than one published names: 16730
# ----------+++++++++++++--------------
# More than one published names: 33115
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 28730
# ----------+++++++++++++--------------
# More than one published names: 351
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 33123
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 24934
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 57706
# ----------+++++++++++++--------------
# More than one published names: 16751
# ----------+++++++++++++--------------
# More than one published names: 16752
# ----------+++++++++++++--------------
# More than one published names: 33137
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 34195
# ----------+++++++++++++--------------
# More than one published names: 24949
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 24954
# ----------+++++++++++++--------------
# More than one published names: 379
# More than one job title: 379
# More than one organisation code: 379
# ----------+++++++++++++--------------
# More than one published names: 33148
# ----------+++++++++++++--------------
# More than one published names: 16773
# More than one organisation code: 16773
# ----------+++++++++++++--------------
# More than one published names: 24969
# ----------+++++++++++++--------------
# More than one published names: 24973
# ----------+++++++++++++--------------
# More than one published names: 24979
# ----------+++++++++++++--------------
# More than one published names: 16788
# ----------+++++++++++++--------------
# More than one published names: 405
# ----------+++++++++++++--------------
# More than one published names: 410
# More than one job title: 410
# More than one organisation code: 410
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 419
# ----------+++++++++++++--------------
# More than one published names: 33188
# ----------+++++++++++++--------------
# More than one published names: 25004
# ----------+++++++++++++--------------
# More than one published names: 63027
# ----------+++++++++++++--------------
# More than one published names: 25011
# ----------+++++++++++++--------------
# More than one published names: 16822
# ----------+++++++++++++--------------
# More than one published names: 442
# ----------+++++++++++++--------------
# More than one published names: 16827
# ----------+++++++++++++--------------
# More than one published names: 33215
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 8643
# ----------+++++++++++++--------------
# More than one job title: 16836
# More than one organisation code: 16836
# ----------+++++++++++++--------------
# More than one published names: 16844
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 468
# ----------+++++++++++++--------------
# More than one published names: 16588
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one job title: 33242
# ----------+++++++++++++--------------
# More than one published names: 31591
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 25058
# ----------+++++++++++++--------------
# More than one published names: 35579
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 25064
# ----------+++++++++++++--------------
# More than one published names: 16874
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 16467
# ----------+++++++++++++--------------
# More than one published names: 16886
# ----------+++++++++++++--------------
# More than one published names: 16889
# ----------+++++++++++++--------------
# More than one published names: 16890
# ----------+++++++++++++--------------
# More than one published names: 16891
# ----------+++++++++++++--------------
# More than one published names: 8708
# ----------+++++++++++++--------------
# More than one published names: 24662
# ----------+++++++++++++--------------
# More than one published names: 16902
# ----------+++++++++++++--------------
# More than one published names: 8716
# More than one job title: 8716
# ----------+++++++++++++--------------
# More than one published names: 16911
# ----------+++++++++++++--------------
# More than one published names: 33296
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 531
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 16919
# ----------+++++++++++++--------------
# More than one job title: 57884
# ----------+++++++++++++--------------
# More than one published names: 28762
# ----------+++++++++++++--------------
# More than one published names: 8734
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 33314
# ----------+++++++++++++--------------
# More than one published names: 16931
# ----------+++++++++++++--------------
# More than one published names: 16938
# ----------+++++++++++++--------------
# More than one published names: 2823
# ----------+++++++++++++--------------
# More than one published names: 27400
# ----------+++++++++++++--------------
# More than one published names: 564
# ----------+++++++++++++--------------
# More than one published names: 24670
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 25145
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 8769
# ----------+++++++++++++--------------
# More than one published names: 16963
# ----------+++++++++++++--------------
# More than one published names: 8775
# ----------+++++++++++++--------------
# More than one published names: 51981
# ----------+++++++++++++--------------
# More than one published names: 16976
# ----------+++++++++++++--------------
# More than one published names: 49747
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 33366
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 16988
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 16991
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 25185
# ----------+++++++++++++--------------
# More than one published names: 25186
# ----------+++++++++++++--------------
# More than one published names: 30139
# ----------+++++++++++++--------------
# More than one published names: 8804
# ----------+++++++++++++--------------
# More than one published names: 33386
# ----------+++++++++++++--------------
# More than one published names: 33387
# More than one job title: 33387
# ----------+++++++++++++--------------
# More than one published names: 17004
# ----------+++++++++++++--------------
# More than one published names: 56082
# ----------+++++++++++++--------------
# More than one published names: 25200
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 66186
# More than one job title: 66186
# ----------+++++++++++++--------------
# More than one published names: 33419
# ----------+++++++++++++--------------
# More than one published names: 25230
# ----------+++++++++++++--------------
# More than one published names: 17041
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 8855
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 33437
# ----------+++++++++++++--------------
# More than one published names: 35611
# ----------+++++++++++++--------------
# More than one published names: 17062
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17065
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 8881
# ----------+++++++++++++--------------
# More than one published names: 8882
# ----------+++++++++++++--------------
# More than one published names: 8883
# ----------+++++++++++++--------------
# More than one published names: 58038
# ----------+++++++++++++--------------
# More than one published names: 33848
# ----------+++++++++++++--------------
# More than one published names: 24692
# ----------+++++++++++++--------------
# More than one published names: 25280
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 31521
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 25289
# ----------+++++++++++++--------------
# More than one published names: 33482
# ----------+++++++++++++--------------
# More than one published names: 25291
# ----------+++++++++++++--------------
# More than one published names: 33488
# ----------+++++++++++++--------------
# More than one published names: 8914
# ----------+++++++++++++--------------
# More than one published names: 723
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 66266
# ----------+++++++++++++--------------
# More than one published names: 8925
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 740
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 33514
# ----------+++++++++++++--------------
# More than one published names: 33516
# ----------+++++++++++++--------------
# More than one published names: 8941
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 11755
# More than one job title: 11755
# ----------+++++++++++++--------------
# More than one published names: 769
# More than one job title: 769
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 25354
# ----------+++++++++++++--------------
# More than one published names: 17163
# ----------+++++++++++++--------------
# More than one published names: 17164
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 33556
# ----------+++++++++++++--------------
# More than one published names: 8982
# ----------+++++++++++++--------------
# More than one published names: 17183
# ----------+++++++++++++--------------
# More than one published names: 8995
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one job title: 805
# ----------+++++++++++++--------------
# More than one published names: 33574
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 9002
# ----------+++++++++++++--------------
# More than one published names: 25388
# ----------+++++++++++++--------------
# More than one published names: 9006
# ----------+++++++++++++--------------
# More than one published names: 25391
# ----------+++++++++++++--------------
# More than one published names: 17201
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 58163
# ----------+++++++++++++--------------
# More than one published names: 9012
# ----------+++++++++++++--------------
# More than one published names: 9013
# ----------+++++++++++++--------------
# More than one published names: 17206
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17221
# ----------+++++++++++++--------------
# More than one published names: 33610
# ----------+++++++++++++--------------
# More than one published names: 33611
# ----------+++++++++++++--------------
# More than one published names: 25424
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 25435
# ----------+++++++++++++--------------
# More than one published names: 9052
# ----------+++++++++++++--------------
# More than one published names: 9053
# ----------+++++++++++++--------------
# More than one published names: 25441
# ----------+++++++++++++--------------
# More than one published names: 17251
# ----------+++++++++++++--------------
# More than one published names: 9063
# ----------+++++++++++++--------------
# More than one published names: 9067
# ----------+++++++++++++--------------
# More than one published names: 878
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17264
# More than one job title: 17264
# ----------+++++++++++++--------------
# More than one published names: 25398
# ----------+++++++++++++--------------
# More than one published names: 885
# ----------+++++++++++++--------------
# More than one published names: 30185
# ----------+++++++++++++--------------
# More than one job title: 25464
# ----------+++++++++++++--------------
# More than one published names: 890
# More than one job title: 890
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17278
# ----------+++++++++++++--------------
# More than one published names: 897
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 9092
# ----------+++++++++++++--------------
# More than one published names: 17285
# ----------+++++++++++++--------------
# More than one published names: 9094
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 25481
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 908
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 25491
# More than one job title: 25491
# ----------+++++++++++++--------------
# More than one published names: 9109
# ----------+++++++++++++--------------
# More than one published names: 20633
# ----------+++++++++++++--------------
# More than one published names: 9112
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 922
# ----------+++++++++++++--------------
# More than one published names: 11077
# ----------+++++++++++++--------------
# More than one published names: 50525
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 33699
# ----------+++++++++++++--------------
# More than one published names: 9124
# ----------+++++++++++++--------------
# More than one published names: 17318
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 33708
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17332
# ----------+++++++++++++--------------
# More than one published names: 9141
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 25531
# ----------+++++++++++++--------------
# More than one published names: 33724
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 46405
# More than one job title: 46405
# ----------+++++++++++++--------------
# More than one published names: 17352
# ----------+++++++++++++--------------
# More than one published names: 969
# ----------+++++++++++++--------------
# More than one published names: 970
# ----------+++++++++++++--------------
# More than one published names: 25548
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 33750
# ----------+++++++++++++--------------
# More than one published names: 25559
# ----------+++++++++++++--------------
# More than one published names: 25560
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 9181
# ----------+++++++++++++--------------
# More than one published names: 25566
# ----------+++++++++++++--------------
# More than one published names: 991
# ----------+++++++++++++--------------
# More than one published names: 17376
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 9186
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 23377
# ----------+++++++++++++--------------
# More than one published names: 9193
# ----------+++++++++++++--------------
# More than one published names: 1002
# ----------+++++++++++++--------------
# More than one published names: 25579
# More than one job title: 25579
# More than one organisation code: 25579
# ----------+++++++++++++--------------
# More than one published names: 25582
# ----------+++++++++++++--------------
# More than one published names: 66544
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17410
# ----------+++++++++++++--------------
# More than one published names: 53421
# ----------+++++++++++++--------------
# More than one published names: 17427
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 33815
# ----------+++++++++++++--------------
# More than one published names: 25625
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 26117
# ----------+++++++++++++--------------
# More than one published names: 66592
# ----------+++++++++++++--------------
# More than one published names: 17447
# ----------+++++++++++++--------------
# More than one published names: 25641
# ----------+++++++++++++--------------
# More than one published names: 25644
# More than one job title: 25644
# More than one organisation code: 25644
# ----------+++++++++++++--------------
# More than one published names: 17455
# ----------+++++++++++++--------------
# More than one published names: 17461
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 33850
# ----------+++++++++++++--------------
# More than one published names: 33854
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 1090
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 33863
# ----------+++++++++++++--------------
# More than one published names: 9288
# ----------+++++++++++++--------------
# More than one published names: 34316
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 33867
# More than one job title: 33867
# More than one organisation code: 33867
# ----------+++++++++++++--------------
# More than one published names: 17488
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 33875
# ----------+++++++++++++--------------
# More than one job title: 17492
# More than one organisation code: 17492
# ----------+++++++++++++--------------
# More than one published names: 17493
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 32953
# More than one job title: 32953
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 26127
# ----------+++++++++++++--------------
# More than one published names: 9309
# More than one job title: 9309
# ----------+++++++++++++--------------
# More than one published names: 9313
# More than one organisation code: 9313
# ----------+++++++++++++--------------
# More than one published names: 9315
# ----------+++++++++++++--------------
# More than one published names: 17508
# More than one job title: 17508
# ----------+++++++++++++--------------
# More than one published names: 9318
# ----------+++++++++++++--------------
# More than one published names: 9319
# ----------+++++++++++++--------------
# More than one published names: 9322
# ----------+++++++++++++--------------
# More than one published names: 25707
# ----------+++++++++++++--------------
# More than one published names: 33901
# More than one job title: 33901
# More than one organisation code: 33901
# ----------+++++++++++++--------------
# More than one published names: 1135
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17522
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 33911
# ----------+++++++++++++--------------
# More than one published names: 33912
# ----------+++++++++++++--------------
# More than one published names: 25721
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 25725
# ----------+++++++++++++--------------
# More than one published names: 57868
# ----------+++++++++++++--------------
# More than one published names: 1152
# ----------+++++++++++++--------------
# More than one published names: 32960
# ----------+++++++++++++--------------
# More than one published names: 25734
# ----------+++++++++++++--------------
# More than one published names: 17545
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17552
# ----------+++++++++++++--------------
# More than one published names: 9361
# ----------+++++++++++++--------------
# More than one published names: 1170
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 1172
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17563
# ----------+++++++++++++--------------
# More than one published names: 1186
# More than one job title: 1186
# ----------+++++++++++++--------------
# More than one published names: 33956
# More than one job title: 33956
# More than one organisation code: 33956
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 1191
# ----------+++++++++++++--------------
# More than one published names: 17576
# ----------+++++++++++++--------------
# More than one published names: 50346
# More than one organisation code: 50346
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 31602
# ----------+++++++++++++--------------
# More than one published names: 33968
# ----------+++++++++++++--------------
# More than one published names: 33973
# ----------+++++++++++++--------------
# More than one published names: 9398
# ----------+++++++++++++--------------
# More than one published names: 25785
# ----------+++++++++++++--------------
# More than one published names: 33982
# ----------+++++++++++++--------------
# More than one published names: 9408
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17604
# ----------+++++++++++++--------------
# More than one published names: 1225
# ----------+++++++++++++--------------
# More than one published names: 33998
# ----------+++++++++++++--------------
# More than one published names: 33866
# ----------+++++++++++++--------------
# More than one published names: 17624
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 25818
# ----------+++++++++++++--------------
# More than one published names: 25819
# ----------+++++++++++++--------------
# More than one published names: 25822
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 66786
# ----------+++++++++++++--------------
# More than one published names: 9443
# ----------+++++++++++++--------------
# More than one published names: 1252
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 25836
# ----------+++++++++++++--------------
# More than one published names: 1261
# ----------+++++++++++++--------------
# More than one published names: 17653
# ----------+++++++++++++--------------
# More than one published names: 17654
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17657
# ----------+++++++++++++--------------
# More than one published names: 25852
# ----------+++++++++++++--------------
# More than one published names: 17662
# ----------+++++++++++++--------------
# More than one published names: 17665
# ----------+++++++++++++--------------
# More than one published names: 17666
# ----------+++++++++++++--------------
# More than one published names: 52144
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17675
# ----------+++++++++++++--------------
# More than one published names: 27522
# ----------+++++++++++++--------------
# More than one published names: 34063
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 1302
# ----------+++++++++++++--------------
# More than one published names: 9495
# ----------+++++++++++++--------------
# More than one published names: 9498
# More than one job title: 9498
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 1309
# ----------+++++++++++++--------------
# More than one published names: 17694
# ----------+++++++++++++--------------
# More than one published names: 17695
# ----------+++++++++++++--------------
# More than one job title: 17697
# ----------+++++++++++++--------------
# More than one published names: 1317
# ----------+++++++++++++--------------
# More than one published names: 17706
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17724
# ----------+++++++++++++--------------
# More than one published names: 17728
# ----------+++++++++++++--------------
# More than one published names: 17729
# ----------+++++++++++++--------------
# More than one published names: 25924
# ----------+++++++++++++--------------
# More than one published names: 17735
# ----------+++++++++++++--------------
# More than one published names: 1352
# ----------+++++++++++++--------------
# More than one published names: 43916
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 25938
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 29506
# ----------+++++++++++++--------------
# More than one published names: 1373
# ----------+++++++++++++--------------
# More than one published names: 34142
# ----------+++++++++++++--------------
# More than one published names: 25956
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 28903
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17779
# ----------+++++++++++++--------------
# More than one published names: 25973
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 25976
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one job title: 54847
# ----------+++++++++++++--------------
# More than one published names: 17791
# ----------+++++++++++++--------------
# More than one published names: 66947
# ----------+++++++++++++--------------
# More than one published names: 1412
# ----------+++++++++++++--------------
# More than one published names: 25989
# ----------+++++++++++++--------------
# More than one job title: 1414
# ----------+++++++++++++--------------
# More than one published names: 33872
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17804
# ----------+++++++++++++--------------
# More than one published names: 34190
# ----------+++++++++++++--------------
# More than one published names: 9615
# ----------+++++++++++++--------------
# More than one published names: 34192
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17811
# ----------+++++++++++++--------------
# More than one published names: 9620
# ----------+++++++++++++--------------
# More than one published names: 9621
# ----------+++++++++++++--------------
# More than one published names: 34199
# ----------+++++++++++++--------------
# More than one published names: 9624
# ----------+++++++++++++--------------
# More than one published names: 26009
# ----------+++++++++++++--------------
# More than one published names: 9626
# ----------+++++++++++++--------------
# More than one published names: 34203
# ----------+++++++++++++--------------
# More than one job title: 17821
# ----------+++++++++++++--------------
# More than one published names: 17825
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 9638
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 34216
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 34218
# ----------+++++++++++++--------------
# More than one published names: 26027
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 26031
# ----------+++++++++++++--------------
# More than one published names: 17840
# ----------+++++++++++++--------------
# More than one published names: 9649
# ----------+++++++++++++--------------
# More than one published names: 34227
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 9654
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 1466
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17852
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17859
# ----------+++++++++++++--------------
# More than one published names: 9668
# ----------+++++++++++++--------------
# More than one published names: 26055
# ----------+++++++++++++--------------
# More than one published names: 9672
# ----------+++++++++++++--------------
# More than one published names: 26059
# More than one job title: 26059
# ----------+++++++++++++--------------
# More than one published names: 26060
# ----------+++++++++++++--------------
# More than one published names: 58832
# ----------+++++++++++++--------------
# More than one published names: 9681
# ----------+++++++++++++--------------
# More than one published names: 34258
# ----------+++++++++++++--------------
# More than one published names: 34259
# ----------+++++++++++++--------------
# More than one published names: 1503
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17897
# ----------+++++++++++++--------------
# More than one published names: 19367
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 9719
# ----------+++++++++++++--------------
# More than one published names: 34296
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17916
# ----------+++++++++++++--------------
# More than one published names: 43946
# ----------+++++++++++++--------------
# More than one published names: 34303
# ----------+++++++++++++--------------
# More than one published names: 33024
# ----------+++++++++++++--------------
# More than one published names: 9733
# ----------+++++++++++++--------------
# More than one published names: 26119
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 34317
# ----------+++++++++++++--------------
# More than one published names: 9742
# ----------+++++++++++++--------------
# More than one published names: 17935
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17938
# ----------+++++++++++++--------------
# More than one published names: 17940
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17951
# ----------+++++++++++++--------------
# More than one published names: 34336
# ----------+++++++++++++--------------
# More than one published names: 43952
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 9776
# ----------+++++++++++++--------------
# More than one published names: 34353
# ----------+++++++++++++--------------
# More than one published names: 28422
# ----------+++++++++++++--------------
# More than one published names: 27571
# ----------+++++++++++++--------------
# More than one published names: 34361
# ----------+++++++++++++--------------
# More than one published names: 34399
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 9801
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 34385
# ----------+++++++++++++--------------
# More than one published names: 29089
# ----------+++++++++++++--------------
# More than one published names: 34387
# ----------+++++++++++++--------------
# More than one published names: 34391
# ----------+++++++++++++--------------
# More than one published names: 67163
# ----------+++++++++++++--------------
# More than one published names: 1631
# ----------+++++++++++++--------------
# More than one published names: 9824
# ----------+++++++++++++--------------
# More than one published names: 26210
# ----------+++++++++++++--------------
# More than one published names: 9828
# ----------+++++++++++++--------------
# More than one published names: 9829
# ----------+++++++++++++--------------
# More than one published names: 9831
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 26219
# ----------+++++++++++++--------------
# More than one published names: 1645
# ----------+++++++++++++--------------
# More than one published names: 26223
# More than one job title: 26223
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 9842
# ----------+++++++++++++--------------
# More than one published names: 9844
# ----------+++++++++++++--------------
# More than one published names: 26234
# ----------+++++++++++++--------------
# More than one published names: 34428
# ----------+++++++++++++--------------
# More than one published names: 18053
# ----------+++++++++++++--------------
# More than one published names: 9866
# ----------+++++++++++++--------------
# More than one published names: 9837
# ----------+++++++++++++--------------
# More than one published names: 1681
# ----------+++++++++++++--------------
# More than one published names: 1682
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 9877
# ----------+++++++++++++--------------
# More than one published names: 26262
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 34464
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 9890
# ----------+++++++++++++--------------
# More than one published names: 18083
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 26284
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 9908
# ----------+++++++++++++--------------
# More than one published names: 1719
# ----------+++++++++++++--------------
# More than one published names: 18105
# ----------+++++++++++++--------------
# More than one published names: 51885
# ----------+++++++++++++--------------
# More than one published names: 26300
# ----------+++++++++++++--------------
# More than one published names: 26303
# ----------+++++++++++++--------------
# More than one published names: 18113
# ...
# More than one published names: 23895
# ----------+++++++++++++--------------
# More than one published names: 32088
# ----------+++++++++++++--------------
# More than one published names: 23900
# ----------+++++++++++++--------------
# More than one published names: 32093
# ----------+++++++++++++--------------
# More than one published names: 32094
# ----------+++++++++++++--------------
# More than one published names: 7520
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 23911
# ----------+++++++++++++--------------
# More than one published names: 23921
# ----------+++++++++++++--------------
# More than one published names: 32659
# ----------+++++++++++++--------------
# More than one published names: 23924
# ----------+++++++++++++--------------
# More than one published names: 7543
# ----------+++++++++++++--------------
# More than one published names: 15739
# ----------+++++++++++++--------------
# More than one published names: 48513
# More than one job title: 48513
# ----------+++++++++++++--------------
# More than one published names: 48514
# More than one job title: 48514
# More than one organisation code: 48514
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 15748
# ----------+++++++++++++--------------
# More than one published names: 23945
# ----------+++++++++++++--------------
# More than one published names: 7562
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 23951
# ----------+++++++++++++--------------
# More than one published names: 23952
# ----------+++++++++++++--------------
# More than one published names: 23953
# ----------+++++++++++++--------------
# More than one published names: 32148
# ----------+++++++++++++--------------
# More than one published names: 23957
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 15774
# ----------+++++++++++++--------------
# More than one published names: 8091
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 23983
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 53173
# ----------+++++++++++++--------------
# More than one published names: 35512
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 27210
# More than one job title: 27210
# ----------+++++++++++++--------------
# More than one published names: 32190
# ----------+++++++++++++--------------
# More than one published names: 24003
# ----------+++++++++++++--------------
# More than one published names: 24005
# ----------+++++++++++++--------------
# More than one published names: 24008
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 48588
# ----------+++++++++++++--------------
# More than one published names: 24018
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 48602
# ----------+++++++++++++--------------
# More than one published names: 48607
# ----------+++++++++++++--------------
# More than one published names: 15846
# ----------+++++++++++++--------------
# More than one published names: 15847
# ----------+++++++++++++--------------
# More than one published names: 15848
# ----------+++++++++++++--------------
# More than one published names: 7658
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 61353
# ----------+++++++++++++--------------
# More than one published names: 7673
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 15872
# ----------+++++++++++++--------------
# More than one published names: 32257
# ----------+++++++++++++--------------
# More than one published names: 7682
# ----------+++++++++++++--------------
# More than one published names: 24069
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 18805
# More than one job title: 18805
# ----------+++++++++++++--------------
# More than one published names: 24074
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 7694
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 32275
# ----------+++++++++++++--------------
# More than one published names: 15892
# ----------+++++++++++++--------------
# More than one published names: 32277
# ----------+++++++++++++--------------
# More than one published names: 15898
# ----------+++++++++++++--------------
# More than one published names: 32283
# ----------+++++++++++++--------------
# More than one published names: 56865
# ----------+++++++++++++--------------
# More than one published names: 24101
# ----------+++++++++++++--------------
# More than one published names: 24102
# ----------+++++++++++++--------------
# More than one published names: 24104
# ----------+++++++++++++--------------
# More than one published names: 7724
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 7739
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 34075
# ----------+++++++++++++--------------
# More than one published names: 31329
# ----------+++++++++++++--------------
# More than one published names: 7752
# ----------+++++++++++++--------------
# More than one published names: 24138
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 7762
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 7768
# ----------+++++++++++++--------------
# More than one published names: 32346
# ----------+++++++++++++--------------
# More than one published names: 24156
# ----------+++++++++++++--------------
# More than one published names: 24157
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 32357
# ----------+++++++++++++--------------
# More than one published names: 32358
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 24175
# ----------+++++++++++++--------------
# More than one published names: 7795
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 32389
# ----------+++++++++++++--------------
# More than one published names: 32391
# ----------+++++++++++++--------------
# More than one published names: 16008
# ----------+++++++++++++--------------
# More than one published names: 16009
# ----------+++++++++++++--------------
# More than one published names: 16012
# ----------+++++++++++++--------------
# More than one published names: 32399
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 16024
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 16027
# ----------+++++++++++++--------------
# More than one published names: 24220
# ----------+++++++++++++--------------
# More than one published names: 24221
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 48802
# ----------+++++++++++++--------------
# More than one published names: 32419
# ----------+++++++++++++--------------
# More than one published names: 32423
# ----------+++++++++++++--------------
# More than one published names: 24234
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 57005
# ----------+++++++++++++--------------
# More than one published names: 24239
# ----------+++++++++++++--------------
# More than one published names: 32433
# ----------+++++++++++++--------------
# More than one published names: 24243
# ----------+++++++++++++--------------
# More than one published names: 24245
# ----------+++++++++++++--------------
# More than one published names: 24246
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 32441
# ----------+++++++++++++--------------
# More than one published names: 50463
# ----------+++++++++++++--------------
# More than one published names: 24258
# ----------+++++++++++++--------------
# More than one published names: 32458
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 32463
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 16090
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 28624
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 32494
# ----------+++++++++++++--------------
# More than one published names: 32500
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 43647
# ----------+++++++++++++--------------
# More than one published names: 53205
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 17707
# ----------+++++++++++++--------------
# More than one published names: 57093
# ----------+++++++++++++--------------
# More than one job title: 65286
# ----------+++++++++++++--------------
# More than one published names: 31361
# ----------+++++++++++++--------------
# More than one published names: 32522
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 24337
# ----------+++++++++++++--------------
# More than one published names: 10473
# ----------+++++++++++++--------------
# More than one published names: 24344
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 24540
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 48946
# More than one job title: 48946
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 24377
# ----------+++++++++++++--------------
# More than one published names: 16192
# ----------+++++++++++++--------------
# More than one published names: 32578
# ----------+++++++++++++--------------
# More than one published names: 48966
# ----------+++++++++++++--------------
# More than one published names: 16199
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 24396
# More than one job title: 24396
# More than one organisation code: 24396
# ----------+++++++++++++--------------
# More than one published names: 24402
# ----------+++++++++++++--------------
# More than one published names: 24404
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 16216
# ----------+++++++++++++--------------
# More than one published names: 48986
# ----------+++++++++++++--------------
# More than one published names: 32603
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 48990
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one job title: 32609
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 32616
# ----------+++++++++++++--------------
# More than one published names: 24428
# ----------+++++++++++++--------------
# More than one published names: 24429
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 24441
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 16252
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 16257
# ----------+++++++++++++--------------
# More than one published names: 16258
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 32645
# ----------+++++++++++++--------------
# More than one published names: 16263
# ----------+++++++++++++--------------
# More than one published names: 24459
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 16272
# ----------+++++++++++++--------------
# More than one published names: 16273
# ----------+++++++++++++--------------
# More than one published names: 8083
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 16283
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 28656
# ----------+++++++++++++--------------
# More than one published names: 16290
# ----------+++++++++++++--------------
# More than one published names: 49062
# ----------+++++++++++++--------------
# More than one published names: 8104
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 16304
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 16308
# ----------+++++++++++++--------------
# More than one published names: 8120
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 32707
# ----------+++++++++++++--------------
# More than one published names: 16324
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 16326
# ----------+++++++++++++--------------
# More than one published names: 8137
# ----------+++++++++++++--------------
# More than one published names: 32732
# ----------+++++++++++++--------------
# More than one published names: 24526
# ----------+++++++++++++--------------
# More than one published names: 16336
# ----------+++++++++++++--------------
# More than one published names: 16339
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 24536
# ----------+++++++++++++--------------
# More than one published names: 8155
# ----------+++++++++++++--------------
# More than one published names: 8156
# ----------+++++++++++++--------------
# More than one published names: 8159
# ----------+++++++++++++--------------
# More than one job title: 32737
# ----------+++++++++++++--------------
# More than one published names: 24548
# ----------+++++++++++++--------------
# More than one published names: 49130
# ----------+++++++++++++--------------
# More than one published names: 8172
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 16371
# ----------+++++++++++++--------------
# ----------+++++++++++++--------------
# More than one published names: 49149
# ----------+++++++++++++--------------
# More than one published names: 8190
# More than one job title: 8190
# More than one organisation code: 8190
# ----------+++++++++++++--------------

# %%
# ...cont
for i, row in staff_record.iterrows():
    staff_record.loc[i, "FORENAME"] = row["FORENAME"][0]
    staff_record.loc[i, "SURNAME"] = row["SURNAME"][0]

# %% [markdown]
# ### Clean job titles ###

# %%
## Collect all job titles
job_titles = []
for i in staff_record["JOB_TITLE"].values:
    for j in i:
        if j not in job_titles:
            job_titles.append(j)
print "There are around %d different job titles among 3263 researchers..." % len(job_titles)
# Out:
# There are around 1426 different job titles among 3263 researchers...

# %%
# job_titles_stop_words = ["in", "of"]
# job_titles_stems = [
#     "Emeritus Professor",
    
#     "Postdoctoral Senior Research Associate",
#     "Postdoctoral Researcher",
#     "Postdoctoral Fellow",
#     "Postdoctoral Research Associate",
#     "Postdoctoral Training Fellow",    

    
#     "Senior Research Associate",
#     "Senior Research and Teaching Associate",
#     "Senior Lecturer",
#     "Senior Clinical Fellow",
#     "Senior Clinical Lecturer",
#     "Senior Research Fellow",
#     "Senior Teaching Fellow",
#     "Senior Teaching Laboratory Technician",
#     "Senior Histology Laboratory Technician",
#     "Senior Scientific Computer Officer",
#     "Senior Experimental Officer (Research)",
    
#     "Clinical Lecturer",
#     "Clinical Teacher",
#     "Clinical Tutor",
#     "Clinical Teaching Fellow",
    
#     "Visiting Fellow",
        
#     "Teaching Associate",
#     "Teaching Fellow",
#     "Senior Associate Teacher",
#     "Assistant Teacher",
        
#     "Faculty Education Manager",
    
            
#     "Research Fellow",
#     "Research Associate",
#     "Research Collaborator",
#     "Research Manager",
    
    
#     "Technician",
#     "Coordinator",
#     "Co-ordinator",
#     "Director",
#     "Manager",
#     "Project Staff",
#     "Administrator",
#     "Secretary",
    
#     "Chair",
#     "Dean",
#     "Head",
        
#     "Professor",
#     "Reader",
#     "Lecturer",
#     "Tutor"
# ]

# import re
# at = re.compile("^\
# (?:Postdoctoral|Faculty|Visiting)?\s?\
# (?:Emeritus|Senior|Assistant)?\s?\
# (?:Clinical|Centre|Trial)?\s?\
# (?:Research|Teaching|Training|Education|Experimental|Scientific)?\s?\
# (?:Laboratory|Project|Computer|Study)?\s?\
# (?:Associate)?\s?\
# (?:Professor|Reader|Lecturer|Tutor|Dean|Chair|Head|Technician|Coordinator|Co-ordinator|Director|Manager|Staff|Administrator|Secretary|Researcher|Fellow|Teacher|Collaborator|Officer)?\
# \s(?:in|of|-)\s\
# (?:.+)?\
# $",
#                 re.IGNORECASE)

def decompose_title(s, reversed=False):
    titles = [
        ["Postdoctoral","Faculty","Visiting", "Doctoral", "Undergraduate"],
        ["Emeritus","Senior","Assistant"],
        ["Clinical","Centre","Trial", "General", "Nursery","Programme", "Data", "Library", "Dental", "IT", "User", "Team", "Technical", "Systems", "Molecular", "HR", "Building"],
        
        ["Research","Teaching","Training","Education","Experimental","Scientific"],
        ["and Research","and Teaching","and Training","and Education","and Experimental","and Scientific"],
        
        ["Laboratory","Project","Computer","Study", "Switchboard"],
        ["Associate"],
        ["Professor","Reader","Lecturer","Tutor","Dean","Chair","Head","Technician","Coordinator","Co-ordinator","Director","Manager","Staff","Administrator","Secretary","Researcher","Fellow","Teacher","Collaborator","Officer", "Chancelor", "Vice-Chancellor", "Assistant", "Supervisor", "Instructor", "Worker", "Receptionist", "Trainer", "Support", "Bioinformatician", "Administrator", "Leader", "Developer", "Consultant", "Demonstrator", "Librarian", "Accountant", "President", "Student", "Geneticist", "Council", "Adviser", "Surveyor", "Selector", "Operator"],
        ["(Research)"]
    ]
    normalised = []
    
    if reversed:
        titles = titles[::-1]
        s = " ".join(s.split(" ")[::-1])
    for j in titles:
        norm_len = len(normalised)
        for i in j:
            if s.startswith(i):
                s = s.lstrip(i).strip()
                normalised.append(i)
                break
        if norm_len == len(normalised):
            normalised.append("")
    if reversed:
        s = " ".join(s.split(" ")[::-1])
        normalised = normalised[::-1]
    return s.strip(), tuple(normalised)

# %%
outs = []
for i in job_titles:
    i = i.replace("/", " ").replace("Lead", "Leader")
    # Forward
    a, an = decompose_title(i)
    # Backward
    if a == i:
        a, an = decompose_title(i, True)
    # Drop words (e.g. XYZ Reader in ABC)
    if a == i:
        changed = False
        a_split = a.split(" ")
        for j in range(1, len(a_split)):
            aa = " ".join(a_split[j:])
            a, an = decompose_title(aa)
            if aa != a:
                changed = True
                break
        if not changed:
            a, an = decompose_title(i)

    outs.append(an)
            
    # Drop title of in at |alt| if extracted something
    #if a == "" or a.startswith("of") or a.startswith("in") or a.startswith("-") or a.startswith(":"):
    if a == i:
        print outs[-1]
print len(outs)
# Out:
# 1426

# %%
# Set unified job titles
for irow, row in staff_record.iterrows():
    ann = []
    for i in row["JOB_TITLE"]:
        i = i.replace("/", " ").replace("Lead", "Leader")
        # Forward
        a, an = decompose_title(i)
        # Backward
        if a == i:
            a, an = decompose_title(i, True)
        # Drop words (e.g. XYZ Reader in ABC)
        if a == i:
            changed = False
            a_split = a.split(" ")
            for j in range(1, len(a_split)):
                aa = " ".join(a_split[j:])
                a, an = decompose_title(aa)
                if aa != a:
                    changed = True
                    break
            if not changed:
                a, an = decompose_title(i)
        ann.append(an)
    
    staff_record.loc[irow, "JOB_TITLE"] = ann

# %%
staff_record.to_pickle("kbs_staff_record.pickle")

# %%
staff_record = pd.read_pickle("kbs_staff_record.pickle")

# %%
staff_record
# Out:
#           FORENAME          SURNAME  \
# 24576      Siobhan          Shilton
# 57346          Tim           Arnold
# 24581        Becky  Conway-Campbell
# 49161      Lyndsay              Coo
# 24586       Joanne            Edgar
# 16395    Francesco         Mezzadri
# 49164        Chris         Howcroft
# 10925        Jamie           Jeremy
# 16403         Emma         Robinson
# 20           David        Armstrong
# 24601       Pamela             King
# 16410      Siobhan           Mullan
# 29734        Sanja       Dogramadzi
# 49182     Kongtana     Trakarnsanga
# 33           Sarah           Barnes
# 8227         Gavin          D'Costa
# 24612         John           Harris
# 24615      Frances         Giampapa
# 32811    Francesco         Fornetti
# 44         Michael           Barton
# 24621      Timothy         Harrison
# 25949      Jessica           Watson
# 24627      Stanley           Zammit
# 16436        Jutta           Weldes
# 16438  Christopher            Adams
# 57           Peter          Bennett
# 16443       Caragh            Wells
# 34918     Michelle           Harris
# 24638     Samantha            Jones
# 43701       Fergal          Monsell
# ...            ...              ...
# 16304       Galina         Bulanova
# 24499     Nicholas        Peatfield
# 16308       Dudley       Shallcross
# 8120         Fiona           Diffin
# 49087         Sean              Fox
# 32707        Janet          Orchard
# 16324         Neil         Scolding
# 49093       Sheena         Vachhani
# 16326      Timothy          Elliott
# 8137          Neil         Williams
# 32732        David            Grant
# 24526     Costanza         Emanueli
# 16336     Nicholas            Brook
# 16339      Richard           Harris
# 16340        David           Morgan
# 57301       Sophia            Adams
# 24536       Mhairi           Gibson
# 8155         Simon        O'Doherty
# 8156        Julian           Hancox
# 8159     Christine          MacLeod
# 32737       Taraka   Davies-Barnard
# 24548      Anthony            Legon
# 49130  Carl Henrik               Ek
# 8172      Michelle             Cini
# 32749      Dominic           Clarke
# 57326     Jonathan          Clayden
# 16371         Paul           Higate
# 49148       Rohini            Terry
# 49149       Sorrel    Langley-Hobbs
# 8190       Terence         McMaster
#
#                                           PUBLISHED_NAME  \
# 24576                    [SM Shilton, Siobhan M Shilton]
# 57346                                       [Tim Arnold]
# 24581        [Becky Conway-Campbell, BL Conway-Campbell]
# 49161                                  [Lyndsay M-L Coo]
# 24586                           [Joanne Edgar, JL Edgar]
# 16395                   [F Mezzadri, Francesco Mezzadri]
# 49164                      [C. Howcroft, Chris Howcroft]
# 10925                                        [JY Jeremy]
# 16403  [Emma S. J. Robinson, Emma S J Robinson, ESJ R...
# 20                                     [David Armstrong]
# 24601                           [Pamela M King, PM King]
# 16410  [Siobhan M Mullan, Siobhan Mullan, Siobhan M. ...
# 29734                                     [S Dogramadzi]
# 49182                            [Kongtana Trakarnsanga]
# 33               [SB Barnes, Sally B Barnes, S B Barnes]
# 8227   [G.G D'Costa, Gavin D'Costa, GG D'Costa, Gavin...
# 24612                                        [JW Harris]
# 24615                                       [F Giampapa]
# 32811                   [Francesco Fornetti, F Fornetti]
# 44                                           [MH Barton]
# 24621                      [TG Harrison, Tim G Harrison]
# 25949                                 [Jessica C Watson]
# 24627  [Stan Zammit, Stanley Zammit, S Zammit, S. Zam...
# 16436                          [Jutta Weldes, JE Weldes]
# 16438  [Christopher J. Adams, CJ Adams, C.J Adams, C....
# 57                                          [PM Bennett]
# 16443                                          [C Wells]
# 34918                                       [MLP Harris]
# 24638                            [SM Jones, Sam M Jones]
# 43701                        [F Monsell, Fergal Monsell]
# ...                                                  ...
# 16304                      [Galina Bulanova, G Bulanova]
# 24499                                     [NJ Peatfield]
# 16308  [DE Shallcross, D.E Shallcross, Dudley E Shall...
# 8120                         [FM Diffin, Fiona M Diffin]
# 49087                                         [Sean Fox]
# 32707                      [JL Orchard, Janet L Orchard]
# 16324  [Neil Scolding, NJ Scolding, N. Scolding, Neil...
# 49093                                [Sheena J Vachhani]
# 16326              [Tim Elliott, T. Elliott, TR Elliott]
# 8137   [N A Williams, N Williams, Neil A Williams, N....
# 32732                         [D G Grant, David G Grant]
# 24526                    [Costanza Emanueli, C Emanueli]
# 16336                 [N.H Brook, N. H. Brook, NH Brook]
# 16339  [RJ Harris, Richard J Harris, Richard Harris, ...
# 16340                                        [DJ Morgan]
# 57301                                   [Sophia A Adams]
# 24536  [MA Gibson, Mhairi A Gibson, M.A Gibson, Mhair...
# 8155   [SJ O'Doherty, Simon O'Doherty, S. J. O'Dohert...
# 8156   [J C Hancox, Jules C Hancox, Jules Hancox, JC ...
# 8159   [C. J A MacLeod, Christine MacLeod, C. J A Mac...
# 32737                                 [T Davies-Barnard]
# 24548      [Anthony C Legon, Anthony C. Legon, AC Legon]
# 49130                          [Carl Ek, Carl Henrik Ek]
# 8172        [Michelle M C Cini, MMC Cini, Michelle Cini]
# 32749                                 [Dominic J Clarke]
# 57326                                 [Jonathan Clayden]
# 16371                         [Paul R Higate, PR Higate]
# 49148                                   [Rohini H Terry]
# 49149  [Sorrel J Langley-Hobbs, Sorrel J. Langley-Hob...
# 8190   [T. J. McMaster, Terence J. McMaster, TJ McMas...
#
#                                                JOB_TITLE ORGANISATION_CODE
# 24576  [(, , , , , , , Reader, ), (, , , Research, , ...            [FREN]
# 57346           [(, , , Research, , , , Collaborator, )]            [CHEM]
# 24581                 [(, , , Research, , , , Fellow, )]            [SOCS]
# 49161                       [(, , , , , , , Lecturer, )]            [CLAS]
# 24586              [(, , , Research, , , Associate, , )]            [VESC]
# 16395                      [(, , , , , , , Professor, )]            [MATH]
# 49164              [(, , , Research, , , Associate, , )]            [AERO]
# 10925              [(, Emeritus, , , , , , Professor, )]            [SOCS]
# 16403                         [(, , , , , , , Reader, )]            [PHPH]
# 20                 [(, Emeritus, , , , , , Professor, )]            [PHPH]
# 24601                 [(, , , Research, , , , Fellow, )]            [ARTF]
# 16410           [(, Senior, , Research, , , , Fellow, )]            [DFAS]
# 29734                 [(Visiting, , , , , , , Fellow, )]            [MECH]
# 49182              [(, , , Research, , , Associate, , )]            [BIOC]
# 33                         [(, , , , , , , Professor, )]            [EDUC]
# 8227                       [(, , , , , , , Professor, )]            [THRS]
# 24612                 [(Visiting, , , , , , , Fellow, )]            [MATH]
# 24615                 [(, Senior, , , , , , Lecturer, )]            [EDUC]
# 32811                 [(, , , Teaching, , , , Fellow, )]            [EENG]
# 44     [(, Senior, , Teaching, , , , Fellow, ), (, Se...      [MVEN, EENG]
# 24621                         [(, , , , , , , Fellow, )]            [CHEM]
# 25949         [(Doctoral, , , Research, , , , Fellow, )]            [SSCM]
# 24627                      [(, , , , , , , Professor, )]            [SSCM]
# 16436                      [(, , , , , , , Professor, )]            [SPAI]
# 16438       [(, , , Teaching, , Laboratory, , Fellow, )]            [CHEM]
# 57                 [(, Emeritus, , , , , , Professor, )]            [PANM]
# 16443                 [(, Senior, , , , , , Lecturer, )]            [HILA]
# 34918                      [(, , , , , , , Assistant, )]            [SOCS]
# 24638                 [(, , , Research, , , , Fellow, )]            [VESC]
# 43701         [(, Senior, Clinical, , , , , Lecturer, )]            [MEED]
# ...                                                  ...               ...
# 16304                 [(, , , Research, , , , Fellow, )]            [GELY]
# 24499         [(, Senior, , , , , Associate, Teacher, )]            [EDUC]
# 16308                      [(, , , , , , , Professor, )]            [CHEM]
# 8120              [(, , , Research, , , , Technician, )]            [BIOC]
# 49087                       [(, , , , , , , Lecturer, )]            [GEOG]
# 32707                 [(, Senior, , , , , , Lecturer, )]            [EDUC]
# 16324                      [(, , , , , , , Professor, )]            [SOCS]
# 49093                 [(, Senior, , , , , , Lecturer, )]            [MGRC]
# 16326                      [(, , , , , , , Professor, )]            [GELY]
# 8137                       [(, , , , , , , Professor, )]            [PANM]
# 32732                 [(, , , Research, , , , Fellow, )]            [SOCS]
# 24526                          [(, , , , , , , Chair, )]            [SOCS]
# 16336                 [(Visiting, , , , , , , Fellow, )]            [PHYS]
# 16339                      [(, , , , , , , Professor, )]            [GEOG]
# 16340                         [(, , , , , , , Reader, )]            [PANM]
# 57301        [(, Senior, , Research, , , Associate, , )]            [ARCH]
# 24536                         [(, , , , , , , Reader, )]            [ARCH]
# 8155                       [(, , , , , , , Professor, )]            [CHEM]
# 8156                       [(, , , , , , , Professor, )]            [PHPH]
# 8159               [(, Emeritus, , , , , , Professor, )]            [HIST]
# 32737  [(, Senior, , Research, , , Associate, , ), (,...            [GEOG]
# 24548              [(, Emeritus, , , , , , Professor, )]            [CHEM]
# 49130                       [(, , , , , , , Lecturer, )]            [COSC]
# 8172                       [(, , , , , , , Professor, )]            [SPAI]
# 32749              [(, , , Research, , , Associate, , )]            [BISC]
# 57326                      [(, , , , , , , Professor, )]            [CHEM]
# 16371                         [(, , , , , , , Reader, )]            [SPAI]
# 49148        [(, Senior, , Research, , , Associate, , )]            [SSCM]
# 49149                          [(, , , , , , , Chair, )]            [VCAD]
# 8190   [(, , , , , , , Director, ), (, , , , , , , Re...      [PHYS, BRDC]
#
# [3263 rows x 5 columns]

# %%
staff_record[staff_record["SURNAME"]=="ABC"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b9d331ed87da> in <module>()
# ----> 1 staff_record[staff_record["SURNAME"]=="ABC"]
#
# NameError: name 'staff_record' is not defined

# %%
staff_record["JOB_TITLE"]
# Out:
# 24576    [(, , , , , , , Reader, ), (, , , Research, , ...
# 57346             [(, , , Research, , , , Collaborator, )]
# 24581                   [(, , , Research, , , , Fellow, )]
# 49161                         [(, , , , , , , Lecturer, )]
# 24586                [(, , , Research, , , Associate, , )]
# 16395                        [(, , , , , , , Professor, )]
# 49164                [(, , , Research, , , Associate, , )]
# 10925                [(, Emeritus, , , , , , Professor, )]
# 16403                           [(, , , , , , , Reader, )]
# 20                   [(, Emeritus, , , , , , Professor, )]
# 24601                   [(, , , Research, , , , Fellow, )]
# 16410             [(, Senior, , Research, , , , Fellow, )]
# 29734                   [(Visiting, , , , , , , Fellow, )]
# 49182                [(, , , Research, , , Associate, , )]
# 33                           [(, , , , , , , Professor, )]
# 8227                         [(, , , , , , , Professor, )]
# 24612                   [(Visiting, , , , , , , Fellow, )]
# 24615                   [(, Senior, , , , , , Lecturer, )]
# 32811                   [(, , , Teaching, , , , Fellow, )]
# 44       [(, Senior, , Teaching, , , , Fellow, ), (, Se...
# 24621                           [(, , , , , , , Fellow, )]
# 25949           [(Doctoral, , , Research, , , , Fellow, )]
# 24627                        [(, , , , , , , Professor, )]
# 16436                        [(, , , , , , , Professor, )]
# 16438         [(, , , Teaching, , Laboratory, , Fellow, )]
# 57                   [(, Emeritus, , , , , , Professor, )]
# 16443                   [(, Senior, , , , , , Lecturer, )]
# 34918                        [(, , , , , , , Assistant, )]
# 24638                   [(, , , Research, , , , Fellow, )]
# 43701           [(, Senior, Clinical, , , , , Lecturer, )]
#                                ...
# 16304                   [(, , , Research, , , , Fellow, )]
# 24499           [(, Senior, , , , , Associate, Teacher, )]
# 16308                        [(, , , , , , , Professor, )]
# 8120                [(, , , Research, , , , Technician, )]
# 49087                         [(, , , , , , , Lecturer, )]
# 32707                   [(, Senior, , , , , , Lecturer, )]
# 16324                        [(, , , , , , , Professor, )]
# 49093                   [(, Senior, , , , , , Lecturer, )]
# 16326                        [(, , , , , , , Professor, )]
# 8137                         [(, , , , , , , Professor, )]
# 32732                   [(, , , Research, , , , Fellow, )]
# 24526                            [(, , , , , , , Chair, )]
# 16336                   [(Visiting, , , , , , , Fellow, )]
# 16339                        [(, , , , , , , Professor, )]
# 16340                           [(, , , , , , , Reader, )]
# 57301          [(, Senior, , Research, , , Associate, , )]
# 24536                           [(, , , , , , , Reader, )]
# 8155                         [(, , , , , , , Professor, )]
# 8156                         [(, , , , , , , Professor, )]
# 8159                 [(, Emeritus, , , , , , Professor, )]
# 32737    [(, Senior, , Research, , , Associate, , ), (,...
# 24548                [(, Emeritus, , , , , , Professor, )]
# 49130                         [(, , , , , , , Lecturer, )]
# 8172                         [(, , , , , , , Professor, )]
# 32749                [(, , , Research, , , Associate, , )]
# 57326                        [(, , , , , , , Professor, )]
# 16371                           [(, , , , , , , Reader, )]
# 49148          [(, Senior, , Research, , , Associate, , )]
# 49149                            [(, , , , , , , Chair, )]
# 8190     [(, , , , , , , Director, ), (, , , , , , , Re...
# Name: JOB_TITLE, dtype: object
