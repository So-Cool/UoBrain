# %% [markdown]
# # Outputs cleanup #

# %%
import pandas as pd
import re
from unidecode import unidecode
import html
from HTMLParser import HTMLParser

# %%
outputs = pd.read_csv("outputs.csv")
authors = pd.read_csv("authors.csv")

# %%
outputs.index = outputs["PUBLICATION_ID"].values

# %%
auths = []
for i in outputs["PUBLICATION_ID"]:
    auths.append(
        authors[authors["PUBLICATION_ID"]==i]["PERSON_ID"].values
                )

# %%
outputs["AUTHORS"] = auths

# %%
del outputs["PUBLICATION_ID"]

# %%
# We dont need both TYPE_NO and TYPE
del outputs["TYPE_NO"]

# %%
print "Number of publications: %15d" % len(outputs["PUBLICATION_MONTH"])
print "Number of NaNs: %23d" % outputs["PUBLICATION_MONTH"].count()
print "Number of available months data: %6d" % (len(outputs["PUBLICATION_MONTH"]) - outputs["PUBLICATION_MONTH"].count())
# Out:
# Number of publications:           34123
# Number of NaNs:                   19502
# Number of available months data:  14621

# %%
print "Number of publications: %15d" % len(outputs["PUBLICATION_YEAR"])
print "Number of NaNs: %23d" % outputs["PUBLICATION_YEAR"].count()
print "Number of available year data: %4d" % (len(outputs["PUBLICATION_YEAR"]) - outputs["PUBLICATION_YEAR"].count())
# Out:
# Number of publications:           34123
# Number of NaNs:                   34123
# Number of available year data:    0

# %%
del outputs["PUBLICATION_DAY"]
del outputs["PUBLICATION_MONTH"]

# %%
x = list(set(outputs["TYPE"]))
contrib_mapping = {}
for i in x:
    ii = i.split("/")
    if ii[0].endswith("journal"):
        contrib_mapping[i] = ("journal", ii[1])
    elif "conference" in ii[0]:
        contrib_mapping[i] = ("conference", ii[1])
    elif "periodical" in ii[0]:
        contrib_mapping[i] = ("periodical", ii[1])
    elif "book" in ii[0]:
        contrib_mapping[i] = ("book", ii[1])
    elif "paper" in ii[0]:
        contrib_mapping[i] = ("paper", ii[1])
    else:
        contrib_mapping[i] = ("other", ii[1])

outputs["TYPE"] = outputs["TYPE"].map(contrib_mapping)

# %%
# split between publications with and without authors
outputs_named = outputs[outputs["AUTHORS"].apply(lambda x: len(x)) > 0]
outputs_nameless = outputs[outputs["AUTHORS"].apply(lambda x: len(x)) == 0]

# %%
print "Nameless papers:", len(outputs_nameless)
print "Named papers:", len(outputs_named)
# Out:
# Nameless papers: 4460
# Named papers: 29663

# %%
# missing keywords
print "Missing KEYWORDS: %f%%" % (100.0*outputs_named["KEYWORDS"].count()/len(outputs_named["KEYWORDS"]))
print "Missing ABSTRACT: %f%%" % (100.0*outputs_named["ABSTRACT"].count()/len(outputs_named["ABSTRACT"]))
# Out:
# Missing KEYWORDS: 20.689074%
# Missing ABSTRACT: 50.308465%

# %% [markdown]
# # Text cleanup #
# * It's difficult to maintain latex notation / chemical physical abbrevs etc. -- worth investigating

# %%
# curate the data
### Handle &amp; etc. -- all of the HTML characters
def amp(s):
    return HTMLParser().unescape(s)
outputs_named["TITLE"] = outputs_named["TITLE"].apply(amp)

## Transofrm unisode into the nearest ASCII representation
def ud(s):
    return unidecode(re.sub(r'\\(....)', r'\u\g<1>', s).decode('unicode_escape'))
outputs_named["TITLE"] = outputs_named["TITLE"].apply(ud)
# Out:
# /Users/kacper/.virtualenvs/py2-data/lib/python2.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/kacper/.virtualenvs/py2-data/lib/python2.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
outputs_named[["AUTHORS", "PUBLICATION_YEAR"]].to_pickle("pub_auth.pickle")

# %%
## Remove HTML tags
###############################################
### http://stackoverflow.com/questions/753052/strip-html-from-strings-in-python
class MLStripper(HTMLParser):
    def __init__(self):
        self.reset()
        self.fed = []
    def handle_data(self, d):
        self.fed.append(d)
    def get_data(self):
        return ''.join(self.fed)

def strip_tags(html):
    s = MLStripper()
    s.feed(html)
    return s.get_data()

outputs_named["TITLE"] = outputs_named["TITLE"].apply(strip_tags)
# Out:
# /Users/kacper/.virtualenvs/py2-data/lib/python2.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
def to_space(s):
    white_char = [".", ",", ":", "?", "!", "'", "`", "\"", \
                  "~", "\t", "\n", "#", "%", "&", "(", ")", \
                  "+", "*", ";", "=", "[", "]", "|", "{", "}", \
                  "<", ">", "\\", "/"]
    white_char.append("-")
    for i in white_char:
        s = s.replace(i, " ")
    return s
outputs_named["TITLE"] = outputs_named["TITLE"].apply(to_space)
# Out:
# /Users/kacper/.virtualenvs/py2-data/lib/python2.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
def to_special(s):
    s = s.replace("_", "")
    s = s.replace("^", "")
    s = s.replace("@", "a")
    # TODO: $ -> to space $$ -> remove everything in between
    s = s.replace("$", " ")
    return s
outputs_named["TITLE"] = outputs_named["TITLE"].apply(to_special)
# Out:
# /Users/kacper/.virtualenvs/py2-data/lib/python2.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
outputs_named["TITLE"] = outputs_named["TITLE"].apply(str.lower)
# Out:
# /Users/kacper/.virtualenvs/py2-data/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
outputs_named["TITLE"].head()
# Out:
# 89664436    crossing the black atlantic for africa or how ...
# 55265799    central venous catheters and outcomes in hemod...
# 53490655                     communication as information use
# 56453104                                              tobacco
# 68562732    citizens and the co creation of public service...
# Name: TITLE, dtype: object

# %%
def process_stirng(s):
    if isinstance(s, str):
        s = amp(s)
        s = ud(s)
        s = strip_tags(s)
        s = to_space(s)
        s = to_special(s)
        s = str.lower(s)
        return s
    else:
        return s

# %%
outputs_named["KEYWORDS"] = outputs_named["KEYWORDS"].apply(process_stirng)
outputs_named["ABSTRACT"] = outputs_named["ABSTRACT"].apply(process_stirng)
# Out:
# /Users/kacper/.virtualenvs/py2-data/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/kacper/.virtualenvs/py2-data/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
outputs_named
# Out:
#                                                       TITLE  \
# 89664436  crossing the black atlantic for africa or how ...
# 55265799  central venous catheters and outcomes in hemod...
# 53490655                   communication as information use
# 56453104                                            tobacco
# 68562732  citizens and the co creation of public service...
# 92016694  catholicism  religious pluralism and education...
# 91245910  electro induced orientational ordering of anis...
# 94611326                                thorns on my tongue
# 86474151  modulators of monocyte and macrophage phenotyp...
# 52102572     data utilization in flood inundation modelling
# 51699744  exploring nuclear motion through conical inter...
# 51691746  musical modernism in the  land without music  ...
# 89112475                                        imam shamil
# 79552849                                  censor or censure
# 98341121  changing provision in healthcare settings in t...
# 49005274  a prototype theory of metrical stress  lexical...
# 49005220                                       introduction
# 49005161  keeping it in the family  re reading anglo nor...
# 49005110  an overview of arthropod genomics  mitogenomic...
# 94732255  special olympics unified sports r  programme c...
# 94492055                  e per fortuna o purtroppo lo sono
# 89665213  some locally self interacting walks on the int...
# 86366554   west african perspectives on ancient egypt  a...
# 51699782  high resolution photofragment translational sp...
# 95092040               alternative  subsequent descriptions
# 79552816  moderate secularism  religion as identity and ...
# 92016597    the bible in a world of religious pluralism ...
# 62796130  using molecular simulation to predict the phys...
# 94500181  in the grip of grief  the materiality of mourn...
# 62695830                                endocrinology cases
# ...                                                     ...
# 22231198  area level deprivation and overall and cause s...
# 22219057  the role of longitudinal cohort studies in epi...
# 21893630  the monkey puzzle  a systematic review of stud...
# 8637042   pericytes from human veins for treatment of my...
# 8443085   unimolecular reactions of peroxy radicals in a...
# 20868755  general principles for the welfare of animals ...
# 20696349  infrared surface photometry of dwarf galaxies ...
# 34877525  trust in the health care provider patient rela...
# 7228158   novel optical techniques for measurements of l...
# 7090222   ecological change during the early emsian  dev...
# 7034862   inositol 1 4 5 trisphosphate receptors and pac...
# 7012679   investigating links between ecology and bifaci...
# 6980342   the protective effect of ophthalmic viscoelast...
# 6906161   mechanochemistry  opportunities for new and cl...
# 34169202  a review of  a student s guide to geophysical ...
# 33951403            online learning with  multiple  kernels
# 9901709   the use of solvent relaxation nmr to study col...
# 2975750   angiotensins and alzheimer s disease  a bench ...
# 2972311   the molecular genetics of sirtuins  associatio...
# 34282717                     making a match for valinomycin
# 7137562   metabolomics  a valuable tool for stem cell mo...
# 33895433           staphylococcal skin disease in livestock
# 33847960  atomization energies from coupled cluster calc...
# 2759783     what is the best way to use conjugate vaccines
# 2952857   calcium channel blockers and alzheimer s disea...
# 2633223   insights into the pathogenesis and pathogenici...
# 2567443   is socioeconomic status in early life associat...
# 2840930   ab degrading enzymes  potential for treatment ...
# 2794018                   is immunisation child protection
# 2308478   mendelian randomization  using genes as instru...
#
#                                  TYPE  PUBLICATION_YEAR  \
# 89664436              (book, chapter)              2012
# 55265799              (book, chapter)              2012
# 53490655              (book, chapter)              2011
# 56453104              (book, chapter)              2013
# 68562732              (book, chapter)              2013
# 92016694              (book, chapter)              2013
# 91245910              (book, chapter)              2013
# 94611326              (book, chapter)              2013
# 86474151              (book, chapter)              2010
# 52102572              (book, chapter)              2010
# 51699744              (book, chapter)              2011
# 51691746              (book, chapter)              2012
# 89112475              (book, chapter)              2012
# 79552849              (book, chapter)              2013
# 98341121              (book, chapter)              2012
# 49005274              (book, chapter)              2013
# 49005220              (book, chapter)              2012
# 49005161              (book, chapter)              2013
# 49005110              (book, chapter)              2013
# 94732255              (book, chapter)              2012
# 94492055              (book, chapter)              2011
# 89665213              (book, chapter)              2012
# 86366554              (book, chapter)              2011
# 51699782              (book, chapter)              2011
# 95092040              (book, chapter)              2013
# 79552816              (book, chapter)              2012
# 92016597              (book, chapter)              2013
# 62796130              (book, chapter)              2011
# 94500181              (book, chapter)              2011
# 62695830              (book, chapter)              2012
# ...                               ...               ...
# 22231198  (journal, systematicreview)              2013
# 22219057  (journal, systematicreview)              2012
# 21893630  (journal, systematicreview)              2012
# 8637042   (journal, systematicreview)              2013
# 8443085   (journal, systematicreview)              2010
# 20868755  (journal, systematicreview)              2013
# 20696349  (journal, systematicreview)              2012
# 34877525  (journal, systematicreview)              2013
# 7228158   (journal, systematicreview)              2011
# 7090222   (journal, systematicreview)              2008
# 7034862   (journal, systematicreview)              2012
# 7012679   (journal, systematicreview)              2009
# 6980342   (journal, systematicreview)              2011
# 6906161   (journal, systematicreview)              2012
# 34169202  (journal, systematicreview)              2013
# 33951403  (journal, systematicreview)              2013
# 9901709   (journal, systematicreview)              2013
# 2975750   (journal, systematicreview)              2009
# 2972311   (journal, systematicreview)              2010
# 34282717  (journal, systematicreview)              2013
# 7137562   (journal, systematicreview)              2012
# 33895433  (journal, systematicreview)              2012
# 33847960  (journal, systematicreview)              2009
# 2759783   (journal, systematicreview)              2011
# 2952857   (journal, systematicreview)              2012
# 2633223   (journal, systematicreview)              2009
# 2567443   (journal, systematicreview)              2009
# 2840930   (journal, systematicreview)              2011
# 2794018   (journal, systematicreview)              2011
# 2308478   (journal, systematicreview)              2008
#
#                                                    KEYWORDS  \
# 89664436                                                NaN
# 55265799                                                NaN
# 53490655                                                NaN
# 56453104                                                NaN
# 68562732                                                NaN
# 92016694                                                NaN
# 91245910  anisotropic pigment nanoparticles  colloids  e...
# 94611326                                                NaN
# 86474151  cd14  cd16   cd14  cd16   dendritic cells  gm ...
# 52102572  data requirements for flood inundation modelli...
# 51699744                                                NaN
# 51691746                                                NaN
# 89112475                                                NaN
# 79552849                                                NaN
# 98341121                                                NaN
# 49005274                                                NaN
# 49005220                                                NaN
# 49005161                                                NaN
# 49005110                                                NaN
# 94732255                                                NaN
# 94492055                                                NaN
# 89665213                                                NaN
# 86366554                                                NaN
# 51699782                                                NaN
# 95092040                                                NaN
# 79552816          human rights  religion  general interest
# 92016597                                                NaN
# 62796130                                                NaN
# 94500181                                                NaN
# 62695830                                                NaN
# ...                                                     ...
# 22231198  all cause mortality  course socioeconomic posi...
# 22219057  epigenomics  dna methylation  life course  lon...
# 21893630  coronary artery atherosclerosis  female cynomo...
# 8637042   stem cells  cardiac repair  gene therapy  angi...
# 8443085                                                 NaN
# 20868755  animal welfare  animal health  animal husbandr...
# 20696349  techniques  photometric  surveys  galaxies  cl...
# 34877525  professional patient relations  quality indica...
# 7228158                                                 NaN
# 7090222                                                 NaN
# 7034862                                                 NaN
# 7012679                                                 NaN
# 6980342                                                 NaN
# 6906161                                                 NaN
# 34169202                                                NaN
# 33951403  large margin classification  protein fold reco...
# 9901709   nuclear magnetic resonance  sodium dodecyl sul...
# 2975750                                                 NaN
# 2972311                                                 NaN
# 34282717  chloride transport  triamino analog  supramole...
# 7137562   biomaterials  mass spectrometry data  regenera...
# 33895433  sheep scab mite  exudative epidermitis  bovine...
# 33847960  thermochemistry  atomization energy  coupled c...
# 2759783                                                 NaN
# 2952857   calcium  cognitive decline  angiotensin conver...
# 2633223                                                 NaN
# 2567443   adolescent  adult  child  drug users  female  ...
# 2840930                                                 NaN
# 2794018                                                 NaN
# 2308478                                                 NaN
#
#                                                    ABSTRACT  \
# 89664436                                                NaN
# 55265799  a significant proportion of incident and preva...
# 53490655  introduction uncertainty is an unavoidable pro...
# 56453104                                                NaN
# 68562732                                                NaN
# 92016694                                                NaN
# 91245910  the response of anisotropic pigment particle s...
# 94611326                                                NaN
# 86474151                                                NaN
# 52102572                                                NaN
# 51699744  the concept of adiabatic electronic potential ...
# 51691746                                                NaN
# 89112475                                                NaN
# 79552849  in discussion of free speech and incitement to...
# 98341121                                                NaN
# 49005274                                                NaN
# 49005220                                                NaN
# 49005161                                                NaN
# 49005110  arthropods represent the largest majority of a...
# 94732255                                                NaN
# 94492055                                                NaN
# 89665213                                                NaN
# 86366554                                                NaN
# 51699782  photofragment translational spectroscopy  pts ...
# 95092040                                                NaN
# 79552816  one of the features of the  cultural turn  in ...
# 92016597                                                NaN
# 62796130                                                NaN
# 94500181                                                NaN
# 62695830                                                NaN
# ...                                                     ...
# 22231198  background  prospective studies have suggested...
# 22219057  longitudinal cohort studies are ideal for inve...
# 21893630  background  it is often suggested that psychos...
# 8637042   stem cell therapies promise to regenerate the ...
# 8443085   peroxy radicals can undergo isomerisation and ...
# 20868755  in 2012  the world organisation for animal hea...
# 20696349  despite its utility in exploring possible spat...
# 34877525  purpose  trust is important for patients and m...
# 7228158   aerosol particles play important roles in a br...
# 7090222   early emsian claystones and marls of the tafil...
# 7034862   intracellular ca2  plays an important role in ...
# 7012679   we apply eco cultural niche modeling  ecnm   u...
# 6980342   background aims to compare ophthalmic viscoela...
# 6906161   the aim of this critical review is to provide ...
# 34169202                                                NaN
# 33951403  this review examines kernel methods for online...
# 9901709   solvent relaxation nuclear magnetic resonance ...
# 2975750   the pathology of alzheimer s disease  ad  feat...
# 2972311   the sirtuins are a family of proteins remarkab...
# 34282717  the natural product valinomycin is a well know...
# 7137562   metabolomics is a method for investigation of ...
# 33895433  cattle   in cattle  staphylococcal infections ...
# 33847960  the atomization energies of the 105 molecules ...
# 2759783                                                 NaN
# 2952857   midlife hypertension is a risk factor for late...
# 2633223   amyloid beta  abeta  cerebral amyloid angiopat...
# 2567443   aim  to conduct a systematic review of longitu...
# 2840930   there is increasing evidence that deficient cl...
# 2794018                                                 NaN
# 2308478   observational epidemiological studies suffer f...
#
#                                      AUTHORS
# 89664436                             [67324]
# 55265799                             [58056]
# 53490655                       [1968, 12503]
# 56453104                      [27487, 22878]
# 68562732                             [64861]
# 92016694                              [8227]
# 91245910                         [2472, 442]
# 94611326                              [6863]
# 86474151                             [11532]
# 52102572                       [28147, 8925]
# 51699744                         [94, 34765]
# 51691746                             [60910]
# 89112475                             [61086]
# 79552849                             [14677]
# 98341121                             [70344]
# 49005274                             [10516]
# 49005220                             [59522]
# 49005161                             [59522]
# 49005110                             [36791]
# 94732255                             [29664]
# 94492055                             [66362]
# 89665213                             [36435]
# 86366554                             [56664]
# 51699782                         [34765, 94]
# 95092040                             [36921]
# 79552816                             [14677]
# 92016597                              [8227]
# 62796130                             [61464]
# 94500181                             [34586]
# 62695830                              [9124]
# ...                                      ...
# 22231198                      [15454, 10783]
# 22219057                      [34498, 10783]
# 21893630                             [10783]
# 8637042                              [24429]
# 8443085                              [30960]
# 20868755                             [16963]
# 20696349                      [11077, 16009]
# 34877525                             [36921]
# 7228158                       [31058, 22409]
# 7090222                       [36610, 30204]
# 7034862                              [34353]
# 7012679                         [184, 24540]
# 6980342                              [19820]
# 6906161                        [2188, 16438]
# 34169202                             [24243]
# 33951403                             [17669]
# 9901709            [2111, 607, 25524, 11855]
# 2975750                              [16844]
# 2972311                              [16844]
# 34282717                      [44382, 17201]
# 7137562                       [23808, 31106]
# 33895433                             [14581]
# 33847960                             [31771]
# 2759783                              [18804]
# 2952857                              [16844]
# 2633223   [25064, 16844, 24245, 6111, 22293]
# 2567443                [21003, 13131, 24670]
# 2840930   [12417, 6111, 16844, 22840, 24245]
# 2794018                              [18804]
# 2308478         [16715, 10783, 28319, 15848]
#
# [29663 rows x 6 columns]

# %%
outputs_named.to_pickle("outputs_cleaned.pickle")
